# %%
# !mkdir -p /content/kitti
# !wget -P /content/kitti/ https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_image_2.zip
# !wget -P /content/kitti/ https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip
# !unzip /content/kitti/data_object_image_2.zip -d /content/kitti/
# !unzip /content/kitti/data_object_label_2.zip -d /content/kitti/
# Out:
# --2025-05-03 02:44:51--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_image_2.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.171.225, 3.5.134.178, 3.5.135.201, ...
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.171.225|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12569945557 (12G) [application/zip]
# Saving to: ‘/content/kitti/data_object_image_2.zip’
#
# data_object_image_2 100%[===================>]  11.71G  21.1MB/s    in 9m 33s
#
# 2025-05-03 02:54:25 (20.9 MB/s) - ‘/content/kitti/data_object_image_2.zip’ saved [12569945557/12569945557]
#
# --2025-05-03 02:54:25--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 3.5.135.11, 3.5.138.109, 52.219.170.5, ...
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|3.5.135.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5601213 (5.3M) [application/zip]
# Saving to: ‘/content/kitti/data_object_label_2.zip’
#
# data_object_label_2 100%[===================>]   5.34M  5.34MB/s    in 1.0s
#
# 2025-05-03 02:54:26 (5.34 MB/s) - ‘/content/kitti/data_object_label_2.zip’ saved [5601213/5601213]
#
# Archive:  /content/kitti/data_object_image_2.zip
#    creating: /content/kitti/training/image_2/
#  extracting: /content/kitti/training/image_2/002480.png
#  extracting: /content/kitti/training/image_2/005952.png
#  extracting: /content/kitti/training/image_2/000709.png
#  extracting: /content/kitti/training/image_2/000814.png
#  extracting: /content/kitti/training/image_2/006192.png
#  extracting: /content/kitti/training/image_2/006017.png
#  extracting: /content/kitti/training/image_2/002731.png
#  extracting: /content/kitti/training/image_2/005295.png
#  extracting: /content/kitti/training/image_2/005347.png
#  extracting: /content/kitti/training/image_2/005326.png
#  extracting: /content/kitti/training/image_2/005713.png
#  extracting: /content/kitti/training/image_2/007000.png
#  extracting: /content/kitti/training/image_2/004353.png
#  extracting: /content/kitti/training/image_2/003969.png
#  extracting: /content/kitti/training/image_2/001973.png
#  extracting: /content/kitti/training/image_2/001440.png
#  extracting: /content/kitti/training/image_2/007083.png
#  extracting: /content/kitti/training/image_2/000166.png
#  extracting: /content/kitti/training/image_2/004479.png
#  extracting: /content/kitti/training/image_2/003732.png
#  extracting: /content/kitti/training/image_2/003998.png
#  extracting: /content/kitti/training/image_2/001768.png
#  extracting: /content/kitti/training/image_2/003576.png
#  extracting: /content/kitti/training/image_2/006565.png
#  extracting: /content/kitti/training/image_2/001665.png
#  extracting: /content/kitti/training/image_2/001604.png
#  extracting: /content/kitti/training/image_2/002037.png
#  extracting: /content/kitti/training/image_2/006729.png
#  extracting: /content/kitti/training/image_2/006666.png
#  extracting: /content/kitti/training/image_2/001928.png
#  extracting: /content/kitti/training/image_2/007175.png
#  extracting: /content/kitti/training/image_2/001303.png
#  extracting: /content/kitti/training/image_2/002893.png
#  extracting: /content/kitti/training/image_2/006514.png
#  extracting: /content/kitti/training/image_2/002445.png
#  extracting: /content/kitti/training/image_2/005183.png
#  extracting: /content/kitti/training/image_2/006688.png
#  extracting: /content/kitti/training/image_2/001083.png
#  extracting: /content/kitti/training/image_2/005950.png
#  extracting: /content/kitti/training/image_2/000649.png
#  extracting: /content/kitti/training/image_2/005488.png
#  extracting: /content/kitti/training/image_2/001456.png
#  extracting: /content/kitti/training/image_2/005091.png
#  extracting: /content/kitti/training/image_2/000946.png
#  extracting: /content/kitti/training/image_2/003063.png
#  extracting: /content/kitti/training/image_2/003944.png
#  extracting: /content/kitti/training/image_2/000228.png
#  extracting: /content/kitti/training/image_2/005904.png
#  extracting: /content/kitti/training/image_2/002274.png
#  extracting: /content/kitti/training/image_2/005069.png
#  extracting: /content/kitti/training/image_2/006011.png
#  extracting: /content/kitti/training/image_2/002942.png
#  extracting: /content/kitti/training/image_2/003887.png
#  extracting: /content/kitti/training/image_2/006863.png
#  extracting: /content/kitti/training/image_2/006324.png
#  extracting: /content/kitti/training/image_2/002627.png
#  extracting: /content/kitti/training/image_2/002437.png
#  extracting: /content/kitti/training/image_2/002894.png
#  extracting: /content/kitti/training/image_2/004121.png
#  extracting: /content/kitti/training/image_2/003942.png
#  extracting: /content/kitti/training/image_2/003876.png
#  extracting: /content/kitti/training/image_2/000671.png
#  extracting: /content/kitti/training/image_2/004735.png
#  extracting: /content/kitti/training/image_2/003837.png
#  extracting: /content/kitti/training/image_2/003218.png
#  extracting: /content/kitti/training/image_2/006476.png
#  extracting: /content/kitti/training/image_2/000913.png
#  extracting: /content/kitti/training/image_2/000921.png
#  extracting: /content/kitti/training/image_2/007144.png
#  extracting: /content/kitti/training/image_2/006205.png
#  extracting: /content/kitti/training/image_2/007121.png
#  extracting: /content/kitti/training/image_2/000549.png
#  extracting: /content/kitti/training/image_2/004275.png
#  extracting: /content/kitti/training/image_2/002795.png
#  extracting: /content/kitti/training/image_2/003670.png
#  extracting: /content/kitti/training/image_2/007140.png
#  extracting: /content/kitti/training/image_2/004100.png
#  extracting: /content/kitti/training/image_2/007188.png
#  extracting: /content/kitti/training/image_2/007235.png
#  extracting: /content/kitti/training/image_2/002612.png
#  extracting: /content/kitti/training/image_2/006289.png
#  extracting: /content/kitti/training/image_2/002406.png
#  extracting: /content/kitti/training/image_2/005755.png
#  extracting: /content/kitti/training/image_2/004368.png
#  extracting: /content/kitti/training/image_2/005192.png
#  extracting: /content/kitti/training/image_2/000163.png
#  extracting: /content/kitti/training/image_2/001229.png
#  extracting: /content/kitti/training/image_2/004036.png
#  extracting: /content/kitti/training/image_2/006216.png
#  extracting: /content/kitti/training/image_2/001394.png
#  extracting: /content/kitti/training/image_2/000894.png
#  extracting: /content/kitti/training/image_2/003293.png
#  extracting: /content/kitti/training/image_2/002474.png
#  extracting: /content/kitti/training/image_2/006360.png
#  extracting: /content/kitti/training/image_2/007271.png
#  extracting: /content/kitti/training/image_2/004064.png
#  extracting: /content/kitti/training/image_2/001038.png
#  extracting: /content/kitti/training/image_2/003072.png
#  extracting: /content/kitti/training/image_2/006133.png
#  extracting: /content/kitti/training/image_2/002007.png
#  extracting: /content/kitti/training/image_2/006845.png
#  extracting: /content/kitti/training/image_2/004852.png
#  extracting: /content/kitti/training/image_2/006323.png
#  extracting: /content/kitti/training/image_2/003222.png
#  extracting: /content/kitti/training/image_2/004169.png
#  extracting: /content/kitti/training/image_2/006738.png
#  extracting: /content/kitti/training/image_2/005628.png
#  extracting: /content/kitti/training/image_2/001842.png
#  extracting: /content/kitti/training/image_2/004363.png
#  extracting: /content/kitti/training/image_2/007115.png
#  extracting: /content/kitti/training/image_2/001598.png
#  extracting: /content/kitti/training/image_2/000147.png
#  extracting: /content/kitti/training/image_2/001024.png
#  extracting: /content/kitti/training/image_2/004356.png
#  extracting: /content/kitti/training/image_2/001504.png
#  extracting: /content/kitti/training/image_2/002261.png
#  extracting: /content/kitti/training/image_2/005283.png
#  extracting: /content/kitti/training/image_2/006850.png
#  extracting: /content/kitti/training/image_2/006615.png
#  extracting: /content/kitti/training/image_2/000967.png
#  extracting: /content/kitti/training/image_2/003628.png
#  extracting: /content/kitti/training/image_2/001879.png
#  extracting: /content/kitti/training/image_2/005981.png
#  extracting: /content/kitti/training/image_2/000929.png
#  extracting: /content/kitti/training/image_2/004089.png
#  extracting: /content/kitti/training/image_2/000466.png
#  extracting: /content/kitti/training/image_2/002493.png
#  extracting: /content/kitti/training/image_2/002941.png
#  extracting: /content/kitti/training/image_2/001475.png
#  extracting: /content/kitti/training/image_2/004939.png
#  extracting: /content/kitti/training/image_2/006358.png
#  extracting: /content/kitti/training/image_2/005104.png
#  extracting: /content/kitti/training/image_2/002860.png
#  extracting: /content/kitti/training/image_2/006759.png
#  extracting: /content/kitti/training/image_2/000791.png
#  extracting: /content/kitti/training/image_2/001465.png
#  extracting: /content/kitti/training/image_2/000162.png
#  extracting: /content/kitti/training/image_2/005484.png
#  extracting: /content/kitti/training/image_2/005231.png
#  extracting: /content/kitti/training/image_2/006317.png
#  extracting: /content/kitti/training/image_2/005590.png
#  extracting: /content/kitti/training/image_2/003402.png
#  extracting: /content/kitti/training/image_2/003440.png
#  extracting: /content/kitti/training/image_2/001526.png
#  extracting: /content/kitti/training/image_2/007439.png
#  extracting: /content/kitti/training/image_2/003542.png
#  extracting: /content/kitti/training/image_2/005340.png
#  extracting: /content/kitti/training/image_2/006607.png
#  extracting: /content/kitti/training/image_2/000247.png
#  extracting: /content/kitti/training/image_2/004592.png
#  extracting: /content/kitti/training/image_2/001929.png
#  extracting: /content/kitti/training/image_2/003709.png
#  extracting: /content/kitti/training/image_2/003556.png
#  extracting: /content/kitti/training/image_2/003442.png
#  extracting: /content/kitti/training/image_2/000412.png
#  extracting: /content/kitti/training/image_2/005984.png
#  extracting: /content/kitti/training/image_2/007156.png
#  extracting: /content/kitti/training/image_2/001678.png
#  extracting: /content/kitti/training/image_2/005978.png
#  extracting: /content/kitti/training/image_2/006532.png
#  extracting: /content/kitti/training/image_2/005553.png
#  extracting: /content/kitti/training/image_2/004515.png
#  extracting: /content/kitti/training/image_2/005211.png
#  extracting: /content/kitti/training/image_2/004158.png
#  extracting: /content/kitti/training/image_2/006331.png
#  extracting: /content/kitti/training/image_2/002689.png
#  extracting: /content/kitti/training/image_2/002311.png
#  extracting: /content/kitti/training/image_2/007357.png
#  extracting: /content/kitti/training/image_2/005229.png
#  extracting: /content/kitti/training/image_2/006544.png
#  extracting: /content/kitti/training/image_2/005944.png
#  extracting: /content/kitti/training/image_2/001020.png
#  extracting: /content/kitti/training/image_2/005582.png
#  extracting: /content/kitti/training/image_2/000965.png
#  extracting: /content/kitti/training/image_2/000313.png
#  extracting: /content/kitti/training/image_2/002161.png
#  extracting: /content/kitti/training/image_2/000969.png
#  extracting: /content/kitti/training/image_2/002599.png
#  extracting: /content/kitti/training/image_2/006832.png
#  extracting: /content/kitti/training/image_2/003783.png
#  extracting: /content/kitti/training/image_2/002750.png
#  extracting: /content/kitti/training/image_2/002087.png
#  extracting: /content/kitti/training/image_2/003324.png
#  extracting: /content/kitti/training/image_2/004967.png
#  extracting: /content/kitti/training/image_2/001766.png
#  extracting: /content/kitti/training/image_2/005847.png
#  extracting: /content/kitti/training/image_2/005201.png
#  extracting: /content/kitti/training/image_2/005237.png
#  extracting: /content/kitti/training/image_2/001657.png
#  extracting: /content/kitti/training/image_2/005427.png
#  extracting: /content/kitti/training/image_2/003299.png
#  extracting: /content/kitti/training/image_2/002163.png
#  extracting: /content/kitti/training/image_2/005869.png
#  extracting: /content/kitti/training/image_2/003650.png
#  extracting: /content/kitti/training/image_2/006310.png
#  extracting: /content/kitti/training/image_2/007288.png
#  extracting: /content/kitti/training/image_2/003185.png
#  extracting: /content/kitti/training/image_2/005656.png
#  extracting: /content/kitti/training/image_2/005907.png
#  extracting: /content/kitti/training/image_2/000689.png
#  extracting: /content/kitti/training/image_2/003796.png
#  extracting: /content/kitti/training/image_2/004860.png
#  extracting: /content/kitti/training/image_2/003594.png
#  extracting: /content/kitti/training/image_2/001527.png
#  extracting: /content/kitti/training/image_2/000943.png
#  extracting: /content/kitti/training/image_2/003140.png
#  extracting: /content/kitti/training/image_2/001450.png
#  extracting: /content/kitti/training/image_2/004294.png
#  extracting: /content/kitti/training/image_2/006190.png
#  extracting: /content/kitti/training/image_2/001340.png
#  extracting: /content/kitti/training/image_2/005109.png
#  extracting: /content/kitti/training/image_2/002241.png
#  extracting: /content/kitti/training/image_2/005531.png
#  extracting: /content/kitti/training/image_2/005442.png
#  extracting: /content/kitti/training/image_2/000284.png
#  extracting: /content/kitti/training/image_2/004080.png
#  extracting: /content/kitti/training/image_2/000795.png
#  extracting: /content/kitti/training/image_2/007278.png
#  extracting: /content/kitti/training/image_2/003787.png
#  extracting: /content/kitti/training/image_2/004934.png
#  extracting: /content/kitti/training/image_2/004554.png
#  extracting: /content/kitti/training/image_2/003097.png
#  extracting: /content/kitti/training/image_2/004975.png
#  extracting: /content/kitti/training/image_2/003426.png
#  extracting: /content/kitti/training/image_2/003681.png
#  extracting: /content/kitti/training/image_2/003313.png
#  extracting: /content/kitti/training/image_2/007070.png
#  extracting: /content/kitti/training/image_2/002031.png
#  extracting: /content/kitti/training/image_2/002128.png
#  extracting: /content/kitti/training/image_2/006908.png
#  extracting: /content/kitti/training/image_2/002428.png
#  extracting: /content/kitti/training/image_2/001580.png
#  extracting: /content/kitti/training/image_2/003455.png
#  extracting: /content/kitti/training/image_2/002525.png
#  extracting: /content/kitti/training/image_2/004413.png
#  extracting: /content/kitti/training/image_2/003408.png
#  extracting: /content/kitti/training/image_2/000221.png
#  extracting: /content/kitti/training/image_2/000535.png
#  extracting: /content/kitti/training/image_2/004300.png
#  extracting: /content/kitti/training/image_2/004682.png
#  extracting: /content/kitti/training/image_2/006956.png
#  extracting: /content/kitti/training/image_2/001900.png
#  extracting: /content/kitti/training/image_2/000861.png
#  extracting: /content/kitti/training/image_2/006712.png
#  extracting: /content/kitti/training/image_2/001833.png
#  extracting: /content/kitti/training/image_2/006415.png
#  extracting: /content/kitti/training/image_2/006404.png
#  extracting: /content/kitti/training/image_2/000959.png
#  extracting: /content/kitti/training/image_2/002206.png
#  extracting: /content/kitti/training/image_2/002147.png
#  extracting: /content/kitti/training/image_2/002700.png
#  extracting: /content/kitti/training/image_2/003564.png
#  extracting: /content/kitti/training/image_2/002518.png
#  extracting: /content/kitti/training/image_2/006109.png
#  extracting: /content/kitti/training/image_2/005111.png
#  extracting: /content/kitti/training/image_2/004653.png
#  extracting: /content/kitti/training/image_2/002012.png
#  extracting: /content/kitti/training/image_2/000734.png
#  extracting: /content/kitti/training/image_2/006507.png
#  extracting: /content/kitti/training/image_2/002726.png
#  extracting: /content/kitti/training/image_2/001339.png
#  extracting: /content/kitti/training/image_2/004212.png
#  extracting: /content/kitti/training/image_2/007037.png
#  extracting: /content/kitti/training/image_2/003928.png
#  extracting: /content/kitti/training/image_2/002506.png
#  extracting: /content/kitti/training/image_2/001529.png
#  extracting: /content/kitti/training/image_2/001953.png
#  extracting: /content/kitti/training/image_2/001071.png
#  extracting: /content/kitti/training/image_2/001353.png
#  extracting: /content/kitti/training/image_2/002370.png
#  extracting: /content/kitti/training/image_2/000952.png
#  extracting: /content/kitti/training/image_2/005131.png
#  extracting: /content/kitti/training/image_2/001869.png
#  extracting: /content/kitti/training/image_2/000842.png
#  extracting: /content/kitti/training/image_2/000520.png
#  extracting: /content/kitti/training/image_2/004659.png
#  extracting: /content/kitti/training/image_2/002072.png
#  extracting: /content/kitti/training/image_2/001767.png
#  extracting: /content/kitti/training/image_2/005527.png
#  extracting: /content/kitti/training/image_2/000124.png
#  extracting: /content/kitti/training/image_2/004165.png
#  extracting: /content/kitti/training/image_2/006746.png
#  extracting: /content/kitti/training/image_2/007021.png
#  extracting: /content/kitti/training/image_2/001365.png
#  extracting: /content/kitti/training/image_2/004278.png
#  extracting: /content/kitti/training/image_2/006655.png
#  extracting: /content/kitti/training/image_2/005164.png
#  extracting: /content/kitti/training/image_2/001898.png
#  extracting: /content/kitti/training/image_2/005608.png
#  extracting: /content/kitti/training/image_2/002073.png
#  extracting: /content/kitti/training/image_2/003991.png
#  extracting: /content/kitti/training/image_2/000203.png
#  extracting: /content/kitti/training/image_2/004728.png
#  extracting: /content/kitti/training/image_2/001266.png
#  extracting: /content/kitti/training/image_2/001044.png
#  extracting: /content/kitti/training/image_2/000578.png
#  extracting: /content/kitti/training/image_2/005169.png
#  extracting: /content/kitti/training/image_2/003677.png
#  extracting: /content/kitti/training/image_2/006093.png
#  extracting: /content/kitti/training/image_2/005365.png
#  extracting: /content/kitti/training/image_2/005140.png
#  extracting: /content/kitti/training/image_2/006604.png
#  extracting: /content/kitti/training/image_2/006095.png
#  extracting: /content/kitti/training/image_2/007466.png
#  extracting: /content/kitti/training/image_2/006423.png
#  extracting: /content/kitti/training/image_2/003358.png
#  extracting: /content/kitti/training/image_2/005547.png
#  extracting: /content/kitti/training/image_2/002532.png
#  extracting: /content/kitti/training/image_2/003970.png
#  extracting: /content/kitti/training/image_2/004282.png
#  extracting: /content/kitti/training/image_2/001176.png
#  extracting: /content/kitti/training/image_2/003031.png
#  extracting: /content/kitti/training/image_2/003799.png
#  extracting: /content/kitti/training/image_2/001758.png
#  extracting: /content/kitti/training/image_2/001674.png
#  extracting: /content/kitti/training/image_2/002652.png
#  extracting: /content/kitti/training/image_2/006942.png
#  extracting: /content/kitti/training/image_2/005279.png
#  extracting: /content/kitti/training/image_2/005188.png
#  extracting: /content/kitti/training/image_2/007416.png
#  extracting: /content/kitti/training/image_2/003210.png
#  extracting: /content/kitti/training/image_2/000272.png
#  extracting: /content/kitti/training/image_2/003752.png
#  extracting: /content/kitti/training/image_2/000192.png
#  extracting: /content/kitti/training/image_2/005783.png
#  extracting: /content/kitti/training/image_2/002160.png
#  extracting: /content/kitti/training/image_2/003879.png
#  extracting: /content/kitti/training/image_2/003654.png
#  extracting: /content/kitti/training/image_2/003040.png
#  extracting: /content/kitti/training/image_2/006990.png
#  extracting: /content/kitti/training/image_2/004050.png
#  extracting: /content/kitti/training/image_2/005519.png
#  extracting: /content/kitti/training/image_2/003706.png
#  extracting: /content/kitti/training/image_2/001037.png
#  extracting: /content/kitti/training/image_2/004639.png
#  extracting: /content/kitti/training/image_2/003617.png
#  extracting: /content/kitti/training/image_2/001005.png
#  extracting: /content/kitti/training/image_2/001231.png
#  extracting: /content/kitti/training/image_2/006945.png
#  extracting: /content/kitti/training/image_2/002725.png
#  extracting: /content/kitti/training/image_2/006100.png
#  extracting: /content/kitti/training/image_2/003826.png
#  extracting: /content/kitti/training/image_2/000740.png
#  extracting: /content/kitti/training/image_2/002402.png
#  extracting: /content/kitti/training/image_2/006029.png
#  extracting: /content/kitti/training/image_2/004177.png
#  extracting: /content/kitti/training/image_2/005802.png
#  extracting: /content/kitti/training/image_2/005150.png
#  extracting: /content/kitti/training/image_2/004807.png
#  extracting: /content/kitti/training/image_2/001940.png
#  extracting: /content/kitti/training/image_2/002737.png
#  extracting: /content/kitti/training/image_2/005636.png
#  extracting: /content/kitti/training/image_2/000707.png
#  extracting: /content/kitti/training/image_2/001839.png
#  extracting: /content/kitti/training/image_2/001194.png
#  extracting: /content/kitti/training/image_2/005649.png
#  extracting: /content/kitti/training/image_2/002338.png
#  extracting: /content/kitti/training/image_2/004210.png
#  extracting: /content/kitti/training/image_2/000306.png
#  extracting: /content/kitti/training/image_2/000928.png
#  extracting: /content/kitti/training/image_2/007265.png
#  extracting: /content/kitti/training/image_2/006285.png
#  extracting: /content/kitti/training/image_2/001208.png
#  extracting: /content/kitti/training/image_2/001806.png
#  extracting: /content/kitti/training/image_2/005909.png
#  extracting: /content/kitti/training/image_2/004636.png
#  extracting: /content/kitti/training/image_2/006714.png
#  extracting: /content/kitti/training/image_2/000016.png
#  extracting: /content/kitti/training/image_2/001956.png
#  extracting: /content/kitti/training/image_2/003802.png
#  extracting: /content/kitti/training/image_2/000937.png
#  extracting: /content/kitti/training/image_2/002452.png
#  extracting: /content/kitti/training/image_2/005016.png
#  extracting: /content/kitti/training/image_2/004598.png
#  extracting: /content/kitti/training/image_2/001762.png
#  extracting: /content/kitti/training/image_2/005077.png
#  extracting: /content/kitti/training/image_2/000729.png
#  extracting: /content/kitti/training/image_2/005750.png
#  extracting: /content/kitti/training/image_2/003167.png
#  extracting: /content/kitti/training/image_2/000551.png
#  extracting: /content/kitti/training/image_2/004801.png
#  extracting: /content/kitti/training/image_2/003444.png
#  extracting: /content/kitti/training/image_2/004331.png
#  extracting: /content/kitti/training/image_2/003470.png
#  extracting: /content/kitti/training/image_2/004151.png
#  extracting: /content/kitti/training/image_2/001178.png
#  extracting: /content/kitti/training/image_2/007219.png
#  extracting: /content/kitti/training/image_2/002318.png
#  extracting: /content/kitti/training/image_2/000701.png
#  extracting: /content/kitti/training/image_2/001622.png
#  extracting: /content/kitti/training/image_2/002507.png
#  extracting: /content/kitti/training/image_2/003531.png
#  extracting: /content/kitti/training/image_2/006502.png
#  extracting: /content/kitti/training/image_2/000077.png
#  extracting: /content/kitti/training/image_2/004954.png
#  extracting: /content/kitti/training/image_2/005256.png
#  extracting: /content/kitti/training/image_2/000103.png
#  extracting: /content/kitti/training/image_2/006380.png
#  extracting: /content/kitti/training/image_2/000828.png
#  extracting: /content/kitti/training/image_2/002786.png
#  extracting: /content/kitti/training/image_2/000606.png
#  extracting: /content/kitti/training/image_2/000188.png
#  extracting: /content/kitti/training/image_2/005507.png
#  extracting: /content/kitti/training/image_2/000151.png
#  extracting: /content/kitti/training/image_2/002415.png
#  extracting: /content/kitti/training/image_2/000743.png
#  extracting: /content/kitti/training/image_2/006275.png
#  extracting: /content/kitti/training/image_2/002130.png
#  extracting: /content/kitti/training/image_2/005021.png
#  extracting: /content/kitti/training/image_2/005764.png
#  extracting: /content/kitti/training/image_2/004582.png
#  extracting: /content/kitti/training/image_2/005982.png
#  extracting: /content/kitti/training/image_2/002531.png
#  extracting: /content/kitti/training/image_2/005299.png
#  extracting: /content/kitti/training/image_2/004657.png
#  extracting: /content/kitti/training/image_2/006234.png
#  extracting: /content/kitti/training/image_2/005481.png
#  extracting: /content/kitti/training/image_2/000212.png
#  extracting: /content/kitti/training/image_2/005003.png
#  extracting: /content/kitti/training/image_2/000493.png
#  extracting: /content/kitti/training/image_2/007358.png
#  extracting: /content/kitti/training/image_2/004271.png
#  extracting: /content/kitti/training/image_2/000902.png
#  extracting: /content/kitti/training/image_2/002443.png
#  extracting: /content/kitti/training/image_2/001204.png
#  extracting: /content/kitti/training/image_2/002329.png
#  extracting: /content/kitti/training/image_2/001783.png
#  extracting: /content/kitti/training/image_2/000878.png
#  extracting: /content/kitti/training/image_2/006431.png
#  extracting: /content/kitti/training/image_2/006157.png
#  extracting: /content/kitti/training/image_2/006241.png
#  extracting: /content/kitti/training/image_2/007246.png
#  extracting: /content/kitti/training/image_2/005724.png
#  extracting: /content/kitti/training/image_2/005337.png
#  extracting: /content/kitti/training/image_2/006526.png
#  extracting: /content/kitti/training/image_2/006504.png
#  extracting: /content/kitti/training/image_2/001388.png
#  extracting: /content/kitti/training/image_2/000410.png
#  extracting: /content/kitti/training/image_2/005101.png
#  extracting: /content/kitti/training/image_2/007161.png
#  extracting: /content/kitti/training/image_2/000513.png
#  extracting: /content/kitti/training/image_2/004710.png
#  extracting: /content/kitti/training/image_2/002503.png
#  extracting: /content/kitti/training/image_2/004843.png
#  extracting: /content/kitti/training/image_2/001782.png
#  extracting: /content/kitti/training/image_2/005311.png
#  extracting: /content/kitti/training/image_2/003461.png
#  extracting: /content/kitti/training/image_2/003574.png
#  extracting: /content/kitti/training/image_2/000964.png
#  extracting: /content/kitti/training/image_2/000146.png
#  extracting: /content/kitti/training/image_2/000459.png
#  extracting: /content/kitti/training/image_2/006104.png
#  extracting: /content/kitti/training/image_2/005307.png
#  extracting: /content/kitti/training/image_2/004422.png
#  extracting: /content/kitti/training/image_2/001117.png
#  extracting: /content/kitti/training/image_2/000507.png
#  extracting: /content/kitti/training/image_2/002174.png
#  extracting: /content/kitti/training/image_2/001919.png
#  extracting: /content/kitti/training/image_2/004242.png
#  extracting: /content/kitti/training/image_2/005865.png
#  extracting: /content/kitti/training/image_2/002141.png
#  extracting: /content/kitti/training/image_2/005027.png
#  extracting: /content/kitti/training/image_2/003067.png
#  extracting: /content/kitti/training/image_2/001874.png
#  extracting: /content/kitti/training/image_2/006251.png
#  extracting: /content/kitti/training/image_2/004780.png
#  extracting: /content/kitti/training/image_2/000169.png
#  extracting: /content/kitti/training/image_2/002590.png
#  extracting: /content/kitti/training/image_2/005880.png
#  extracting: /content/kitti/training/image_2/001563.png
#  extracting: /content/kitti/training/image_2/004460.png
#  extracting: /content/kitti/training/image_2/005937.png
#  extracting: /content/kitti/training/image_2/000492.png
#  extracting: /content/kitti/training/image_2/006529.png
#  extracting: /content/kitti/training/image_2/004611.png
#  extracting: /content/kitti/training/image_2/005078.png
#  extracting: /content/kitti/training/image_2/001052.png
#  extracting: /content/kitti/training/image_2/000879.png
#  extracting: /content/kitti/training/image_2/001011.png
#  extracting: /content/kitti/training/image_2/000453.png
#  extracting: /content/kitti/training/image_2/000214.png
#  extracting: /content/kitti/training/image_2/001489.png
#  extracting: /content/kitti/training/image_2/005429.png
#  extracting: /content/kitti/training/image_2/000956.png
#  extracting: /content/kitti/training/image_2/002494.png
#  extracting: /content/kitti/training/image_2/004143.png
#  extracting: /content/kitti/training/image_2/007067.png
#  extracting: /content/kitti/training/image_2/001551.png
#  extracting: /content/kitti/training/image_2/007263.png
#  extracting: /content/kitti/training/image_2/006916.png
#  extracting: /content/kitti/training/image_2/003305.png
#  extracting: /content/kitti/training/image_2/000072.png
#  extracting: /content/kitti/training/image_2/001712.png
#  extracting: /content/kitti/training/image_2/002470.png
#  extracting: /content/kitti/training/image_2/001943.png
#  extracting: /content/kitti/training/image_2/000245.png
#  extracting: /content/kitti/training/image_2/004078.png
#  extracting: /content/kitti/training/image_2/007325.png
#  extracting: /content/kitti/training/image_2/001685.png
#  extracting: /content/kitti/training/image_2/005186.png
#  extracting: /content/kitti/training/image_2/001424.png
#  extracting: /content/kitti/training/image_2/004288.png
#  extracting: /content/kitti/training/image_2/007107.png
#  extracting: /content/kitti/training/image_2/001788.png
#  extracting: /content/kitti/training/image_2/006950.png
#  extracting: /content/kitti/training/image_2/005808.png
#  extracting: /content/kitti/training/image_2/000587.png
#  extracting: /content/kitti/training/image_2/001596.png
#  extracting: /content/kitti/training/image_2/001298.png
#  extracting: /content/kitti/training/image_2/003084.png
#  extracting: /content/kitti/training/image_2/004925.png
#  extracting: /content/kitti/training/image_2/007322.png
#  extracting: /content/kitti/training/image_2/006509.png
#  extracting: /content/kitti/training/image_2/006576.png
#  extracting: /content/kitti/training/image_2/000516.png
#  extracting: /content/kitti/training/image_2/000573.png
#  extracting: /content/kitti/training/image_2/000773.png
#  extracting: /content/kitti/training/image_2/003766.png
#  extracting: /content/kitti/training/image_2/000035.png
#  extracting: /content/kitti/training/image_2/000557.png
#  extracting: /content/kitti/training/image_2/004021.png
#  extracting: /content/kitti/training/image_2/004200.png
#  extracting: /content/kitti/training/image_2/003311.png
#  extracting: /content/kitti/training/image_2/005196.png
#  extracting: /content/kitti/training/image_2/000275.png
#  extracting: /content/kitti/training/image_2/002302.png
#  extracting: /content/kitti/training/image_2/001219.png
#  extracting: /content/kitti/training/image_2/003627.png
#  extracting: /content/kitti/training/image_2/001952.png
#  extracting: /content/kitti/training/image_2/002838.png
#  extracting: /content/kitti/training/image_2/001447.png
#  extracting: /content/kitti/training/image_2/002301.png
#  extracting: /content/kitti/training/image_2/006816.png
#  extracting: /content/kitti/training/image_2/002098.png
#  extracting: /content/kitti/training/image_2/000922.png
#  extracting: /content/kitti/training/image_2/005883.png
#  extracting: /content/kitti/training/image_2/006810.png
#  extracting: /content/kitti/training/image_2/004043.png
#  extracting: /content/kitti/training/image_2/004216.png
#  extracting: /content/kitti/training/image_2/000724.png
#  extracting: /content/kitti/training/image_2/002484.png
#  extracting: /content/kitti/training/image_2/002131.png
#  extracting: /content/kitti/training/image_2/005049.png
#  extracting: /content/kitti/training/image_2/000154.png
#  extracting: /content/kitti/training/image_2/001725.png
#  extracting: /content/kitti/training/image_2/000462.png
#  extracting: /content/kitti/training/image_2/004992.png
#  extracting: /content/kitti/training/image_2/007221.png
#  extracting: /content/kitti/training/image_2/004493.png
#  extracting: /content/kitti/training/image_2/003712.png
#  extracting: /content/kitti/training/image_2/002933.png
#  extracting: /content/kitti/training/image_2/002851.png
#  extracting: /content/kitti/training/image_2/001039.png
#  extracting: /content/kitti/training/image_2/002418.png
#  extracting: /content/kitti/training/image_2/007072.png
#  extracting: /content/kitti/training/image_2/005234.png
#  extracting: /content/kitti/training/image_2/004866.png
#  extracting: /content/kitti/training/image_2/001851.png
#  extracting: /content/kitti/training/image_2/001656.png
#  extracting: /content/kitti/training/image_2/006869.png
#  extracting: /content/kitti/training/image_2/005489.png
#  extracting: /content/kitti/training/image_2/003782.png
#  extracting: /content/kitti/training/image_2/003424.png
#  extracting: /content/kitti/training/image_2/003949.png
#  extracting: /content/kitti/training/image_2/000390.png
#  extracting: /content/kitti/training/image_2/006237.png
#  extracting: /content/kitti/training/image_2/002384.png
#  extracting: /content/kitti/training/image_2/006028.png
#  extracting: /content/kitti/training/image_2/004061.png
#  extracting: /content/kitti/training/image_2/007004.png
#  extracting: /content/kitti/training/image_2/000073.png
#  extracting: /content/kitti/training/image_2/003595.png
#  extracting: /content/kitti/training/image_2/007275.png
#  extracting: /content/kitti/training/image_2/004898.png
#  extracting: /content/kitti/training/image_2/003434.png
#  extracting: /content/kitti/training/image_2/002376.png
#  extracting: /content/kitti/training/image_2/005567.png
#  extracting: /content/kitti/training/image_2/000304.png
#  extracting: /content/kitti/training/image_2/002637.png
#  extracting: /content/kitti/training/image_2/005333.png
#  extracting: /content/kitti/training/image_2/002230.png
#  extracting: /content/kitti/training/image_2/004669.png
#  extracting: /content/kitti/training/image_2/003660.png
#  extracting: /content/kitti/training/image_2/000809.png
#  extracting: /content/kitti/training/image_2/006634.png
#  extracting: /content/kitti/training/image_2/003924.png
#  extracting: /content/kitti/training/image_2/000093.png
#  extracting: /content/kitti/training/image_2/005696.png
#  extracting: /content/kitti/training/image_2/002164.png
#  extracting: /content/kitti/training/image_2/005093.png
#  extracting: /content/kitti/training/image_2/001273.png
#  extracting: /content/kitti/training/image_2/000371.png
#  extracting: /content/kitti/training/image_2/004459.png
#  extracting: /content/kitti/training/image_2/006794.png
#  extracting: /content/kitti/training/image_2/005589.png
#  extracting: /content/kitti/training/image_2/006842.png
#  extracting: /content/kitti/training/image_2/006934.png
#  extracting: /content/kitti/training/image_2/001753.png
#  extracting: /content/kitti/training/image_2/006897.png
#  extracting: /content/kitti/training/image_2/000862.png
#  extracting: /content/kitti/training/image_2/005423.png
#  extracting: /content/kitti/training/image_2/006936.png
#  extracting: /content/kitti/training/image_2/001070.png
#  extracting: /content/kitti/training/image_2/005035.png
#  extracting: /content/kitti/training/image_2/002432.png
#  extracting: /content/kitti/training/image_2/003885.png
#  extracting: /content/kitti/training/image_2/003272.png
#  extracting: /content/kitti/training/image_2/006417.png
#  extracting: /content/kitti/training/image_2/005117.png
#  extracting: /content/kitti/training/image_2/003328.png
#  extracting: /content/kitti/training/image_2/001230.png
#  extracting: /content/kitti/training/image_2/005844.png
#  extracting: /content/kitti/training/image_2/006163.png
#  extracting: /content/kitti/training/image_2/004265.png
#  extracting: /content/kitti/training/image_2/005209.png
#  extracting: /content/kitti/training/image_2/005287.png
#  extracting: /content/kitti/training/image_2/003736.png
#  extracting: /content/kitti/training/image_2/002278.png
#  extracting: /content/kitti/training/image_2/006767.png
#  extracting: /content/kitti/training/image_2/002562.png
#  extracting: /content/kitti/training/image_2/005071.png
#  extracting: /content/kitti/training/image_2/006294.png
#  extracting: /content/kitti/training/image_2/005704.png
#  extracting: /content/kitti/training/image_2/000483.png
#  extracting: /content/kitti/training/image_2/005116.png
#  extracting: /content/kitti/training/image_2/004160.png
#  extracting: /content/kitti/training/image_2/006300.png
#  extracting: /content/kitti/training/image_2/004730.png
#  extracting: /content/kitti/training/image_2/001309.png
#  extracting: /content/kitti/training/image_2/007201.png
#  extracting: /content/kitti/training/image_2/002008.png
#  extracting: /content/kitti/training/image_2/000217.png
#  extracting: /content/kitti/training/image_2/004192.png
#  extracting: /content/kitti/training/image_2/005120.png
#  extracting: /content/kitti/training/image_2/003861.png
#  extracting: /content/kitti/training/image_2/003587.png
#  extracting: /content/kitti/training/image_2/005454.png
#  extracting: /content/kitti/training/image_2/005391.png
#  extracting: /content/kitti/training/image_2/003877.png
#  extracting: /content/kitti/training/image_2/006092.png
#  extracting: /content/kitti/training/image_2/007335.png
#  extracting: /content/kitti/training/image_2/006329.png
#  extracting: /content/kitti/training/image_2/003327.png
#  extracting: /content/kitti/training/image_2/001041.png
#  extracting: /content/kitti/training/image_2/005931.png
#  extracting: /content/kitti/training/image_2/006168.png
#  extracting: /content/kitti/training/image_2/005945.png
#  extracting: /content/kitti/training/image_2/005677.png
#  extracting: /content/kitti/training/image_2/002243.png
#  extracting: /content/kitti/training/image_2/003778.png
#  extracting: /content/kitti/training/image_2/005285.png
#  extracting: /content/kitti/training/image_2/004508.png
#  extracting: /content/kitti/training/image_2/004658.png
#  extracting: /content/kitti/training/image_2/007126.png
#  extracting: /content/kitti/training/image_2/006276.png
#  extracting: /content/kitti/training/image_2/000677.png
#  extracting: /content/kitti/training/image_2/003322.png
#  extracting: /content/kitti/training/image_2/004727.png
#  extracting: /content/kitti/training/image_2/003259.png
#  extracting: /content/kitti/training/image_2/006722.png
#  extracting: /content/kitti/training/image_2/006993.png
#  extracting: /content/kitti/training/image_2/003359.png
#  extracting: /content/kitti/training/image_2/003403.png
#  extracting: /content/kitti/training/image_2/003518.png
#  extracting: /content/kitti/training/image_2/003839.png
#  extracting: /content/kitti/training/image_2/006161.png
#  extracting: /content/kitti/training/image_2/003162.png
#  extracting: /content/kitti/training/image_2/002844.png
#  extracting: /content/kitti/training/image_2/004148.png
#  extracting: /content/kitti/training/image_2/006002.png
#  extracting: /content/kitti/training/image_2/003267.png
#  extracting: /content/kitti/training/image_2/002661.png
#  extracting: /content/kitti/training/image_2/005814.png
#  extracting: /content/kitti/training/image_2/001840.png
#  extracting: /content/kitti/training/image_2/006265.png
#  extracting: /content/kitti/training/image_2/000615.png
#  extracting: /content/kitti/training/image_2/001497.png
#  extracting: /content/kitti/training/image_2/002482.png
#  extracting: /content/kitti/training/image_2/005218.png
#  extracting: /content/kitti/training/image_2/006327.png
#  extracting: /content/kitti/training/image_2/002334.png
#  extracting: /content/kitti/training/image_2/003060.png
#  extracting: /content/kitti/training/image_2/000152.png
#  extracting: /content/kitti/training/image_2/000935.png
#  extracting: /content/kitti/training/image_2/002686.png
#  extracting: /content/kitti/training/image_2/007223.png
#  extracting: /content/kitti/training/image_2/004739.png
#  extracting: /content/kitti/training/image_2/003616.png
#  extracting: /content/kitti/training/image_2/006773.png
#  extracting: /content/kitti/training/image_2/000475.png
#  extracting: /content/kitti/training/image_2/004958.png
#  extracting: /content/kitti/training/image_2/006141.png
#  extracting: /content/kitti/training/image_2/000266.png
#  extracting: /content/kitti/training/image_2/000290.png
#  extracting: /content/kitti/training/image_2/002299.png
#  extracting: /content/kitti/training/image_2/000806.png
#  extracting: /content/kitti/training/image_2/002342.png
#  extracting: /content/kitti/training/image_2/005349.png
#  extracting: /content/kitti/training/image_2/000164.png
#  extracting: /content/kitti/training/image_2/002082.png
#  extracting: /content/kitti/training/image_2/003586.png
#  extracting: /content/kitti/training/image_2/004366.png
#  extracting: /content/kitti/training/image_2/002433.png
#  extracting: /content/kitti/training/image_2/005712.png
#  extracting: /content/kitti/training/image_2/006527.png
#  extracting: /content/kitti/training/image_2/002954.png
#  extracting: /content/kitti/training/image_2/003776.png
#  extracting: /content/kitti/training/image_2/002691.png
#  extracting: /content/kitti/training/image_2/002199.png
#  extracting: /content/kitti/training/image_2/004055.png
#  extracting: /content/kitti/training/image_2/001841.png
#  extracting: /content/kitti/training/image_2/007132.png
#  extracting: /content/kitti/training/image_2/003589.png
#  extracting: /content/kitti/training/image_2/002412.png
#  extracting: /content/kitti/training/image_2/000596.png
#  extracting: /content/kitti/training/image_2/005665.png
#  extracting: /content/kitti/training/image_2/004124.png
#  extracting: /content/kitti/training/image_2/000629.png
#  extracting: /content/kitti/training/image_2/001755.png
#  extracting: /content/kitti/training/image_2/001318.png
#  extracting: /content/kitti/training/image_2/004833.png
#  extracting: /content/kitti/training/image_2/003462.png
#  extracting: /content/kitti/training/image_2/001228.png
#  extracting: /content/kitti/training/image_2/001993.png
#  extracting: /content/kitti/training/image_2/006654.png
#  extracting: /content/kitti/training/image_2/004346.png
#  extracting: /content/kitti/training/image_2/007378.png
#  extracting: /content/kitti/training/image_2/003646.png
#  extracting: /content/kitti/training/image_2/000628.png
#  extracting: /content/kitti/training/image_2/005987.png
#  extracting: /content/kitti/training/image_2/004436.png
#  extracting: /content/kitti/training/image_2/007249.png
#  extracting: /content/kitti/training/image_2/005707.png
#  extracting: /content/kitti/training/image_2/006528.png
#  extracting: /content/kitti/training/image_2/003052.png
#  extracting: /content/kitti/training/image_2/004542.png
#  extracting: /content/kitti/training/image_2/004648.png
#  extracting: /content/kitti/training/image_2/004986.png
#  extracting: /content/kitti/training/image_2/003351.png
#  extracting: /content/kitti/training/image_2/003871.png
#  extracting: /content/kitti/training/image_2/004822.png
#  extracting: /content/kitti/training/image_2/003321.png
#  extracting: /content/kitti/training/image_2/005357.png
#  extracting: /content/kitti/training/image_2/001213.png
#  extracting: /content/kitti/training/image_2/005373.png
#  extracting: /content/kitti/training/image_2/007079.png
#  extracting: /content/kitti/training/image_2/002783.png
#  extracting: /content/kitti/training/image_2/003795.png
#  extracting: /content/kitti/training/image_2/000489.png
#  extracting: /content/kitti/training/image_2/003726.png
#  extracting: /content/kitti/training/image_2/006558.png
#  extracting: /content/kitti/training/image_2/003661.png
#  extracting: /content/kitti/training/image_2/007245.png
#  extracting: /content/kitti/training/image_2/001815.png
#  extracting: /content/kitti/training/image_2/000381.png
#  extracting: /content/kitti/training/image_2/006656.png
#  extracting: /content/kitti/training/image_2/006988.png
#  extracting: /content/kitti/training/image_2/007400.png
#  extracting: /content/kitti/training/image_2/005580.png
#  extracting: /content/kitti/training/image_2/004418.png
#  extracting: /content/kitti/training/image_2/002018.png
#  extracting: /content/kitti/training/image_2/006044.png
#  extracting: /content/kitti/training/image_2/000230.png
#  extracting: /content/kitti/training/image_2/006486.png
#  extracting: /content/kitti/training/image_2/002266.png
#  extracting: /content/kitti/training/image_2/005989.png
#  extracting: /content/kitti/training/image_2/004594.png
#  extracting: /content/kitti/training/image_2/005901.png
#  extracting: /content/kitti/training/image_2/004850.png
#  extracting: /content/kitti/training/image_2/000018.png
#  extracting: /content/kitti/training/image_2/006559.png
#  extracting: /content/kitti/training/image_2/005322.png
#  extracting: /content/kitti/training/image_2/001232.png
#  extracting: /content/kitti/training/image_2/002888.png
#  extracting: /content/kitti/training/image_2/000233.png
#  extracting: /content/kitti/training/image_2/000447.png
#  extracting: /content/kitti/training/image_2/000102.png
#  extracting: /content/kitti/training/image_2/004277.png
#  extracting: /content/kitti/training/image_2/001564.png
#  extracting: /content/kitti/training/image_2/004893.png
#  extracting: /content/kitti/training/image_2/006581.png
#  extracting: /content/kitti/training/image_2/003584.png
#  extracting: /content/kitti/training/image_2/006619.png
#  extracting: /content/kitti/training/image_2/006560.png
#  extracting: /content/kitti/training/image_2/004890.png
#  extracting: /content/kitti/training/image_2/001888.png
#  extracting: /content/kitti/training/image_2/004789.png
#  extracting: /content/kitti/training/image_2/006018.png
#  extracting: /content/kitti/training/image_2/000897.png
#  extracting: /content/kitti/training/image_2/000891.png
#  extracting: /content/kitti/training/image_2/001813.png
#  extracting: /content/kitti/training/image_2/003478.png
#  extracting: /content/kitti/training/image_2/001615.png
#  extracting: /content/kitti/training/image_2/005263.png
#  extracting: /content/kitti/training/image_2/003911.png
#  extracting: /content/kitti/training/image_2/007436.png
#  extracting: /content/kitti/training/image_2/004746.png
#  extracting: /content/kitti/training/image_2/005252.png
#  extracting: /content/kitti/training/image_2/002756.png
#  extracting: /content/kitti/training/image_2/000161.png
#  extracting: /content/kitti/training/image_2/003409.png
#  extracting: /content/kitti/training/image_2/002212.png
#  extracting: /content/kitti/training/image_2/003165.png
# ...
#  extracting: /content/kitti/testing/image_2/000039.png
#  extracting: /content/kitti/testing/image_2/004226.png
#  extracting: /content/kitti/testing/image_2/001927.png
#  extracting: /content/kitti/testing/image_2/005789.png
#  extracting: /content/kitti/testing/image_2/003954.png
#  extracting: /content/kitti/testing/image_2/003496.png
#  extracting: /content/kitti/testing/image_2/003683.png
#  extracting: /content/kitti/testing/image_2/001419.png
#  extracting: /content/kitti/testing/image_2/000968.png
#  extracting: /content/kitti/testing/image_2/006145.png
#  extracting: /content/kitti/testing/image_2/006774.png
#  extracting: /content/kitti/testing/image_2/004892.png
#  extracting: /content/kitti/testing/image_2/007254.png
#  extracting: /content/kitti/testing/image_2/002088.png
#  extracting: /content/kitti/testing/image_2/006719.png
#  extracting: /content/kitti/testing/image_2/007386.png
#  extracting: /content/kitti/testing/image_2/004812.png
#  extracting: /content/kitti/testing/image_2/000424.png
#  extracting: /content/kitti/testing/image_2/001065.png
#  extracting: /content/kitti/testing/image_2/004111.png
#  extracting: /content/kitti/testing/image_2/006733.png
#  extracting: /content/kitti/testing/image_2/000575.png
#  extracting: /content/kitti/testing/image_2/006647.png
#  extracting: /content/kitti/testing/image_2/006926.png
#  extracting: /content/kitti/testing/image_2/004313.png
#  extracting: /content/kitti/testing/image_2/000656.png
#  extracting: /content/kitti/testing/image_2/005561.png
#  extracting: /content/kitti/testing/image_2/004430.png
#  extracting: /content/kitti/testing/image_2/005180.png
#  extracting: /content/kitti/testing/image_2/004496.png
#  extracting: /content/kitti/testing/image_2/005006.png
#  extracting: /content/kitti/testing/image_2/003651.png
#  extracting: /content/kitti/testing/image_2/001904.png
#  extracting: /content/kitti/testing/image_2/006972.png
#  extracting: /content/kitti/testing/image_2/000095.png
#  extracting: /content/kitti/testing/image_2/000881.png
#  extracting: /content/kitti/testing/image_2/003079.png
#  extracting: /content/kitti/testing/image_2/000004.png
#  extracting: /content/kitti/testing/image_2/002808.png
#  extracting: /content/kitti/testing/image_2/002457.png
#  extracting: /content/kitti/testing/image_2/006064.png
#  extracting: /content/kitti/testing/image_2/005765.png
#  extracting: /content/kitti/testing/image_2/002857.png
#  extracting: /content/kitti/testing/image_2/000495.png
#  extracting: /content/kitti/testing/image_2/001951.png
#  extracting: /content/kitti/testing/image_2/005983.png
#  extracting: /content/kitti/testing/image_2/005158.png
#  extracting: /content/kitti/testing/image_2/005260.png
#  extracting: /content/kitti/testing/image_2/000788.png
#  extracting: /content/kitti/testing/image_2/004816.png
#  extracting: /content/kitti/testing/image_2/000593.png
#  extracting: /content/kitti/testing/image_2/000678.png
#  extracting: /content/kitti/testing/image_2/005660.png
#  extracting: /content/kitti/testing/image_2/000115.png
#  extracting: /content/kitti/testing/image_2/001030.png
#  extracting: /content/kitti/testing/image_2/005002.png
#  extracting: /content/kitti/testing/image_2/006039.png
#  extracting: /content/kitti/testing/image_2/007309.png
#  extracting: /content/kitti/testing/image_2/005437.png
#  extracting: /content/kitti/testing/image_2/007406.png
#  extracting: /content/kitti/testing/image_2/002513.png
#  extracting: /content/kitti/testing/image_2/000394.png
#  extracting: /content/kitti/testing/image_2/001243.png
#  extracting: /content/kitti/testing/image_2/000782.png
#  extracting: /content/kitti/testing/image_2/006051.png
#  extracting: /content/kitti/testing/image_2/004510.png
#  extracting: /content/kitti/testing/image_2/000083.png
#  extracting: /content/kitti/testing/image_2/004506.png
#  extracting: /content/kitti/testing/image_2/002847.png
#  extracting: /content/kitti/testing/image_2/002799.png
#  extracting: /content/kitti/testing/image_2/004624.png
#  extracting: /content/kitti/testing/image_2/004642.png
#  extracting: /content/kitti/testing/image_2/001437.png
#  extracting: /content/kitti/testing/image_2/006826.png
#  extracting: /content/kitti/testing/image_2/003953.png
#  extracting: /content/kitti/testing/image_2/001098.png
#  extracting: /content/kitti/testing/image_2/007158.png
#  extracting: /content/kitti/testing/image_2/000099.png
#  extracting: /content/kitti/testing/image_2/005355.png
#  extracting: /content/kitti/testing/image_2/006046.png
#  extracting: /content/kitti/testing/image_2/005118.png
#  extracting: /content/kitti/testing/image_2/006954.png
#  extracting: /content/kitti/testing/image_2/001184.png
#  extracting: /content/kitti/testing/image_2/004763.png
#  extracting: /content/kitti/testing/image_2/002757.png
#  extracting: /content/kitti/testing/image_2/007194.png
#  extracting: /content/kitti/testing/image_2/006958.png
#  extracting: /content/kitti/testing/image_2/003629.png
#  extracting: /content/kitti/testing/image_2/001873.png
#  extracting: /content/kitti/testing/image_2/000991.png
#  extracting: /content/kitti/testing/image_2/002492.png
#  extracting: /content/kitti/testing/image_2/005715.png
#  extracting: /content/kitti/testing/image_2/001505.png
#  extracting: /content/kitti/testing/image_2/004323.png
#  extracting: /content/kitti/testing/image_2/007073.png
#  extracting: /content/kitti/testing/image_2/006040.png
#  extracting: /content/kitti/testing/image_2/007051.png
#  extracting: /content/kitti/testing/image_2/005410.png
#  extracting: /content/kitti/testing/image_2/006102.png
#  extracting: /content/kitti/testing/image_2/000759.png
#  extracting: /content/kitti/testing/image_2/005530.png
#  extracting: /content/kitti/testing/image_2/003229.png
#  extracting: /content/kitti/testing/image_2/000889.png
#  extracting: /content/kitti/testing/image_2/002752.png
#  extracting: /content/kitti/testing/image_2/004539.png
#  extracting: /content/kitti/testing/image_2/000797.png
#  extracting: /content/kitti/testing/image_2/001307.png
#  extracting: /content/kitti/testing/image_2/004879.png
#  extracting: /content/kitti/testing/image_2/005862.png
#  extracting: /content/kitti/testing/image_2/004514.png
#  extracting: /content/kitti/testing/image_2/004467.png
#  extracting: /content/kitti/testing/image_2/004707.png
#  extracting: /content/kitti/testing/image_2/007215.png
#  extracting: /content/kitti/testing/image_2/004724.png
#  extracting: /content/kitti/testing/image_2/006061.png
#  extracting: /content/kitti/testing/image_2/005658.png
#  extracting: /content/kitti/testing/image_2/001518.png
#  extracting: /content/kitti/testing/image_2/001119.png
#  extracting: /content/kitti/testing/image_2/001600.png
#  extracting: /content/kitti/testing/image_2/001891.png
#  extracting: /content/kitti/testing/image_2/004397.png
#  extracting: /content/kitti/testing/image_2/004252.png
#  extracting: /content/kitti/testing/image_2/004704.png
#  extracting: /content/kitti/testing/image_2/005554.png
#  extracting: /content/kitti/testing/image_2/001271.png
#  extracting: /content/kitti/testing/image_2/001013.png
#  extracting: /content/kitti/testing/image_2/000446.png
#  extracting: /content/kitti/testing/image_2/001832.png
#  extracting: /content/kitti/testing/image_2/006013.png
#  extracting: /content/kitti/testing/image_2/005176.png
#  extracting: /content/kitti/testing/image_2/006992.png
#  extracting: /content/kitti/testing/image_2/006569.png
#  extracting: /content/kitti/testing/image_2/004873.png
#  extracting: /content/kitti/testing/image_2/003680.png
#  extracting: /content/kitti/testing/image_2/004966.png
#  extracting: /content/kitti/testing/image_2/001837.png
#  extracting: /content/kitti/testing/image_2/005603.png
#  extracting: /content/kitti/testing/image_2/000836.png
#  extracting: /content/kitti/testing/image_2/000387.png
#  extracting: /content/kitti/testing/image_2/003066.png
#  extracting: /content/kitti/testing/image_2/001100.png
#  extracting: /content/kitti/testing/image_2/005688.png
#  extracting: /content/kitti/testing/image_2/006564.png
#  extracting: /content/kitti/testing/image_2/004683.png
#  extracting: /content/kitti/testing/image_2/007413.png
#  extracting: /content/kitti/testing/image_2/000355.png
#  extracting: /content/kitti/testing/image_2/003978.png
#  extracting: /content/kitti/testing/image_2/003899.png
#  extracting: /content/kitti/testing/image_2/000751.png
#  extracting: /content/kitti/testing/image_2/003141.png
#  extracting: /content/kitti/testing/image_2/001045.png
#  extracting: /content/kitti/testing/image_2/002481.png
#  extracting: /content/kitti/testing/image_2/003857.png
#  extracting: /content/kitti/testing/image_2/001401.png
#  extracting: /content/kitti/testing/image_2/002601.png
#  extracting: /content/kitti/testing/image_2/001099.png
#  extracting: /content/kitti/testing/image_2/002193.png
#  extracting: /content/kitti/testing/image_2/005570.png
#  extracting: /content/kitti/testing/image_2/001690.png
#  extracting: /content/kitti/testing/image_2/001431.png
#  extracting: /content/kitti/testing/image_2/001485.png
#  extracting: /content/kitti/testing/image_2/006827.png
#  extracting: /content/kitti/testing/image_2/000334.png
#  extracting: /content/kitti/testing/image_2/002552.png
#  extracting: /content/kitti/testing/image_2/003973.png
#  extracting: /content/kitti/testing/image_2/003380.png
#  extracting: /content/kitti/testing/image_2/000505.png
#  extracting: /content/kitti/testing/image_2/001043.png
#  extracting: /content/kitti/testing/image_2/004684.png
#  extracting: /content/kitti/testing/image_2/004489.png
#  extracting: /content/kitti/testing/image_2/004622.png
#  extracting: /content/kitti/testing/image_2/005233.png
#  extracting: /content/kitti/testing/image_2/003178.png
#  extracting: /content/kitti/testing/image_2/002896.png
#  extracting: /content/kitti/testing/image_2/005319.png
#  extracting: /content/kitti/testing/image_2/003330.png
#  extracting: /content/kitti/testing/image_2/005371.png
#  extracting: /content/kitti/testing/image_2/003007.png
#  extracting: /content/kitti/testing/image_2/000268.png
#  extracting: /content/kitti/testing/image_2/005939.png
#  extracting: /content/kitti/testing/image_2/003947.png
#  extracting: /content/kitti/testing/image_2/001064.png
#  extracting: /content/kitti/testing/image_2/002444.png
#  extracting: /content/kitti/testing/image_2/006008.png
#  extracting: /content/kitti/testing/image_2/006232.png
#  extracting: /content/kitti/testing/image_2/003480.png
#  extracting: /content/kitti/testing/image_2/000278.png
#  extracting: /content/kitti/testing/image_2/005821.png
#  extracting: /content/kitti/testing/image_2/006159.png
#  extracting: /content/kitti/testing/image_2/006088.png
#  extracting: /content/kitti/testing/image_2/003791.png
#  extracting: /content/kitti/testing/image_2/002325.png
#  extracting: /content/kitti/testing/image_2/003347.png
#  extracting: /content/kitti/testing/image_2/005414.png
#  extracting: /content/kitti/testing/image_2/002914.png
#  extracting: /content/kitti/testing/image_2/001818.png
#  extracting: /content/kitti/testing/image_2/001452.png
#  extracting: /content/kitti/testing/image_2/004319.png
#  extracting: /content/kitti/testing/image_2/006726.png
#  extracting: /content/kitti/testing/image_2/003446.png
#  extracting: /content/kitti/testing/image_2/002280.png
#  extracting: /content/kitti/testing/image_2/005328.png
#  extracting: /content/kitti/testing/image_2/001890.png
#  extracting: /content/kitti/testing/image_2/004017.png
#  extracting: /content/kitti/testing/image_2/005824.png
#  extracting: /content/kitti/testing/image_2/005980.png
#  extracting: /content/kitti/testing/image_2/004186.png
#  extracting: /content/kitti/testing/image_2/000634.png
#  extracting: /content/kitti/testing/image_2/006929.png
#  extracting: /content/kitti/testing/image_2/000670.png
#  extracting: /content/kitti/testing/image_2/003813.png
#  extracting: /content/kitti/testing/image_2/006347.png
#  extracting: /content/kitti/testing/image_2/000022.png
#  extracting: /content/kitti/testing/image_2/004895.png
#  extracting: /content/kitti/testing/image_2/002366.png
#  extracting: /content/kitti/testing/image_2/005622.png
#  extracting: /content/kitti/testing/image_2/006802.png
#  extracting: /content/kitti/testing/image_2/005000.png
#  extracting: /content/kitti/testing/image_2/000768.png
#  extracting: /content/kitti/testing/image_2/003363.png
#  extracting: /content/kitti/testing/image_2/004405.png
#  extracting: /content/kitti/testing/image_2/001042.png
#  extracting: /content/kitti/testing/image_2/003878.png
#  extracting: /content/kitti/testing/image_2/003294.png
#  extracting: /content/kitti/testing/image_2/007222.png
#  extracting: /content/kitti/testing/image_2/001333.png
#  extracting: /content/kitti/testing/image_2/003418.png
#  extracting: /content/kitti/testing/image_2/003174.png
#  extracting: /content/kitti/testing/image_2/005281.png
#  extracting: /content/kitti/testing/image_2/003784.png
#  extracting: /content/kitti/testing/image_2/002814.png
#  extracting: /content/kitti/testing/image_2/004953.png
#  extracting: /content/kitti/testing/image_2/001203.png
#  extracting: /content/kitti/testing/image_2/006822.png
#  extracting: /content/kitti/testing/image_2/005856.png
#  extracting: /content/kitti/testing/image_2/007065.png
#  extracting: /content/kitti/testing/image_2/003242.png
#  extracting: /content/kitti/testing/image_2/006962.png
#  extracting: /content/kitti/testing/image_2/000171.png
#  extracting: /content/kitti/testing/image_2/006124.png
#  extracting: /content/kitti/testing/image_2/006881.png
#  extracting: /content/kitti/testing/image_2/003950.png
#  extracting: /content/kitti/testing/image_2/001910.png
#  extracting: /content/kitti/testing/image_2/000572.png
#  extracting: /content/kitti/testing/image_2/004011.png
#  extracting: /content/kitti/testing/image_2/007129.png
#  extracting: /content/kitti/testing/image_2/005228.png
#  extracting: /content/kitti/testing/image_2/000658.png
#  extracting: /content/kitti/testing/image_2/005383.png
#  extracting: /content/kitti/testing/image_2/004086.png
#  extracting: /content/kitti/testing/image_2/002191.png
#  extracting: /content/kitti/testing/image_2/006622.png
#  extracting: /content/kitti/testing/image_2/003459.png
#  extracting: /content/kitti/testing/image_2/003150.png
#  extracting: /content/kitti/testing/image_2/004095.png
#  extracting: /content/kitti/testing/image_2/003577.png
#  extracting: /content/kitti/testing/image_2/003717.png
#  extracting: /content/kitti/testing/image_2/004849.png
#  extracting: /content/kitti/testing/image_2/004517.png
#  extracting: /content/kitti/testing/image_2/006006.png
#  extracting: /content/kitti/testing/image_2/005045.png
#  extracting: /content/kitti/testing/image_2/000838.png
#  extracting: /content/kitti/testing/image_2/004097.png
#  extracting: /content/kitti/testing/image_2/003373.png
#  extracting: /content/kitti/testing/image_2/003487.png
#  extracting: /content/kitti/testing/image_2/000037.png
#  extracting: /content/kitti/testing/image_2/000075.png
#  extracting: /content/kitti/testing/image_2/005517.png
#  extracting: /content/kitti/testing/image_2/006823.png
#  extracting: /content/kitti/testing/image_2/000090.png
#  extracting: /content/kitti/testing/image_2/003882.png
#  extracting: /content/kitti/testing/image_2/002974.png
#  extracting: /content/kitti/testing/image_2/005001.png
#  extracting: /content/kitti/testing/image_2/006513.png
#  extracting: /content/kitti/testing/image_2/005926.png
#  extracting: /content/kitti/testing/image_2/007122.png
#  extracting: /content/kitti/testing/image_2/004919.png
#  extracting: /content/kitti/testing/image_2/005652.png
#  extracting: /content/kitti/testing/image_2/001834.png
#  extracting: /content/kitti/testing/image_2/000558.png

# %%
# !pip install ultralytics albumentations tqdm opencv-python

# %%
# !pip install albumentations

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import shutil
import random
from sklearn.model_selection import train_test_split
import torch
from ultralytics import YOLO
from PIL import Image
from collections import defaultdict
import albumentations as A  # You'll need to install this: pip install albumentations

# Define paths
DATA_ROOT = "/content/kitti"
IMAGE_DIR = os.path.join(DATA_ROOT, "training/image_2")
LABEL_DIR = os.path.join(DATA_ROOT, "training/label_2")
OUTPUT_DIR = os.path.join(DATA_ROOT, "yolo_dataset")

# Create directories for YOLO format
os.makedirs(os.path.join(OUTPUT_DIR, "images", "train"), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_DIR, "images", "val"), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_DIR, "labels", "train"), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_DIR, "labels", "val"), exist_ok=True)

# KITTI categories to YOLO class mapping
# In YOLO format, we'll use class indices 0:car, 1:van, 2:truck, 3:pedestrian, 4:cyclist
kitti_to_yolo = {
    'Car': 0,
    'Van': 1,
    'Truck': 2,
    'Pedestrian': 3,
    'Cyclist': 4,
    # Ignore other categories
}

def convert_kitti_to_yolo(kitti_label_path, img_width, img_height):
    """
    Convert KITTI format labels to YOLO format:
    YOLO format: <class> <x_center> <y_center> <width> <height>
    where all values are normalized between 0 and 1
    """
    yolo_labels = []
    
    with open(kitti_label_path, 'r') as f:
        lines = f.readlines()
        
    for line in lines:
        parts = line.strip().split(' ')
        obj_class = parts[0]
        
        # Skip if not in our selected classes
        if obj_class not in kitti_to_yolo:
            continue
            
        # KITTI format: [left, top, right, bottom] in pixels
        bbox_left = float(parts[4])
        bbox_top = float(parts[5])
        bbox_right = float(parts[6])
        bbox_bottom = float(parts[7])
        
        # Convert to YOLO format: [x_center, y_center, width, height] normalized
        x_center = ((bbox_left + bbox_right) / 2) / img_width
        y_center = ((bbox_top + bbox_bottom) / 2) / img_height
        width = (bbox_right - bbox_left) / img_width
        height = (bbox_bottom - bbox_top) / img_height
        
        # Add to labels in YOLO format
        yolo_label = f"{kitti_to_yolo[obj_class]} {x_center} {y_center} {width} {height}"
        yolo_labels.append(yolo_label)
        
    return yolo_labels

def create_dataset_visualization(images_list):
    """Create visualization of class distribution in dataset"""
    class_counts = {k: 0 for k in kitti_to_yolo.keys()}
    
    for img_name in tqdm(images_list):
        label_path = os.path.join(LABEL_DIR, img_name.replace('.png', '.txt'))
        
        with open(label_path, 'r') as f:
            lines = f.readlines()
            
        for line in lines:
            parts = line.strip().split(' ')
            obj_class = parts[0]
            if obj_class in kitti_to_yolo:
                class_counts[obj_class] += 1
    
    # Plot distribution
    plt.figure(figsize=(10, 6))
    plt.bar(class_counts.keys(), class_counts.values())
    plt.title('Class Distribution in KITTI Dataset')
    plt.xlabel('Class')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'class_distribution.png'))
    plt.show()
    
    return class_counts

def preprocess_data():
    """Preprocess KITTI data and convert to YOLO format"""
    # Get all image files
    image_files = [f for f in os.listdir(IMAGE_DIR) if f.endswith('.png')]
    
    # Analyze class distribution
    class_counts = create_dataset_visualization(image_files)
    print(f"Class distribution: {class_counts}")
    
    # Split into train and validation sets
    train_images, val_images = train_test_split(image_files, test_size=0.2, random_state=42)
    
    # Process and copy training data
    for img_name in tqdm(train_images, desc="Processing training data"):
        img_path = os.path.join(IMAGE_DIR, img_name)
        label_path = os.path.join(LABEL_DIR, img_name.replace('.png', '.txt'))
        
        # Get image dimensions
        img = cv2.imread(img_path)
        img_height, img_width = img.shape[:2]
        
        # Convert labels to YOLO format
        yolo_labels = convert_kitti_to_yolo(label_path, img_width, img_height)
        
        # Skip images with no valid labels (no objects in our selected classes)
        if not yolo_labels:
            continue
        
        # Copy image
        shutil.copy(img_path, os.path.join(OUTPUT_DIR, "images", "train", img_name))
        
        # Write YOLO labels
        with open(os.path.join(OUTPUT_DIR, "labels", "train", img_name.replace('.png', '.txt')), 'w') as f:
            f.write('\n'.join(yolo_labels))
    
    # Process and copy validation data
    for img_name in tqdm(val_images, desc="Processing validation data"):
        img_path = os.path.join(IMAGE_DIR, img_name)
        label_path = os.path.join(LABEL_DIR, img_name.replace('.png', '.txt'))
        
        # Get image dimensions
        img = cv2.imread(img_path)
        img_height, img_width = img.shape[:2]
        
        # Convert labels to YOLO format
        yolo_labels = convert_kitti_to_yolo(label_path, img_width, img_height)
        
        # Skip images with no valid labels
        if not yolo_labels:
            continue
        
        # Copy image
        shutil.copy(img_path, os.path.join(OUTPUT_DIR, "images", "val", img_name))
        
        # Write YOLO labels
        with open(os.path.join(OUTPUT_DIR, "labels", "val", img_name.replace('.png', '.txt')), 'w') as f:
            f.write('\n'.join(yolo_labels))

def implement_class_balancing(target_classes=["Cyclist", "Truck"]):
    """
    Implement class-specific balancing for target classes using:
    1. Oversampling - duplicate images with target classes
    2. Augmentation - apply transformations to images with target classes
    
    Args:
        target_classes: List of classes to balance
    """
    print(f"Implementing class balancing for: {target_classes}")
    
    # Define paths for training data
    train_images_dir = os.path.join(OUTPUT_DIR, "images", "train")
    train_labels_dir = os.path.join(OUTPUT_DIR, "labels", "train")
    
    # Create directory for augmented data
    augmented_dir = os.path.join(OUTPUT_DIR, "augmented")
    os.makedirs(os.path.join(augmented_dir, "images"), exist_ok=True)
    os.makedirs(os.path.join(augmented_dir, "labels"), exist_ok=True)
    
    # Reverse mapping for easy reference
    yolo_to_kitti = {v: k for k, v in kitti_to_yolo.items()}
    
    # Find all images containing our target classes
    target_class_ids = [kitti_to_yolo[cls] for cls in target_classes]
    images_with_target_classes = defaultdict(list)
    
    print("Scanning dataset for target classes...")
    for label_file in tqdm(os.listdir(train_labels_dir)):
        image_file = label_file.replace('.txt', '.png')
        image_path = os.path.join(train_images_dir, image_file)
        label_path = os.path.join(train_labels_dir, label_file)
        
        # Skip if image doesn't exist
        if not os.path.exists(image_path):
            continue
        
        # Check if file contains target classes
        with open(label_path, 'r') as f:
            lines = f.readlines()
            
        for line in lines:
            # First convert to float, then to int to handle values like '0.0'
            class_id = int(float(line.strip().split(' ')[0]))
            if class_id in target_class_ids:
                images_with_target_classes[class_id].append((image_path, label_path))
                break
    
    # Count instances of each class
    class_counts = {cls_id: len(images) for cls_id, images in images_with_target_classes.items()}
    print(f"Found images with target classes: {class_counts}")
    
    # Determine how many augmentations to create for each class
    # We'll aim for similar numbers of the target classes
    max_count = max(class_counts.values()) if class_counts else 0
    if max_count == 0:
        print("No images found with target classes. Cannot proceed with balancing.")
        return
    
    target_counts = {}
    for cls_id in target_class_ids:
        current_count = class_counts.get(cls_id, 0)
        if current_count == 0:
            print(f"Warning: No images found for class {yolo_to_kitti[cls_id]}")
            continue
            
        # Calculate how many more samples we need
        target_counts[cls_id] = max_count
        
    print(f"Target counts per class: {target_counts}")
    
    # Define strong augmentation pipeline
    augmentation_pipeline = A.Compose([
        # Geometric transformations
        A.HorizontalFlip(p=0.5),
        A.RandomRotate90(p=0.2),
        A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.2, rotate_limit=15, p=0.5),
        
        # Color transformations
        A.RandomBrightnessContrast(brightness_limit=0.3, contrast_limit=0.3, p=0.5),
        A.HueSaturationValue(hue_shift_limit=15, sat_shift_limit=25, val_shift_limit=10, p=0.3),
        A.GaussianBlur(blur_limit=(3, 7), p=0.2),  # Fixed: using GaussianBlur instead of GaussNoise with var_limit
        
        # Weather simulations for autonomous driving
        A.RandomFog(fog_coef_lower=0.1, fog_coef_upper=0.3, p=0.1),  # Note: these params might need to be checked
        A.RandomRain(p=0.1),  # Removed problematic parameters
        A.RandomShadow(shadow_roi=(0, 0.5, 1, 1), p=0.2),
    ], bbox_params=A.BboxParams(format='yolo', label_fields=['class_ids']))  # Fixed: specify YOLO format directly
    
    # Process each target class
    print("Generating balanced dataset...")
    for cls_id in target_class_ids:
        class_name = yolo_to_kitti[cls_id]
        
        if cls_id not in class_counts or class_counts[cls_id] == 0:
            print(f"Skipping {class_name}: no source images")
            continue
            
        current_count = class_counts[cls_id]
        target_count = target_counts[cls_id]
        images_to_generate = target_count - current_count
        
        if images_to_generate <= 0:
            print(f"No additional images needed for {class_name}")
            continue
            
        print(f"Generating {images_to_generate} additional images for {class_name}")
        
        # Get source images for this class
        source_images = images_with_target_classes[cls_id]
        
        # Augment or duplicate images
        augmentation_count = 0
        duplication_count = 0
        
        for i in tqdm(range(images_to_generate)):
            # Pick a random source image
            img_path, label_path = random.choice(source_images)
            img_name = os.path.basename(img_path)
            label_name = os.path.basename(label_path)
            
            # Decide whether to augment or duplicate
            if random.random() < 0.7:  # 70% chance to augment
                # Read image and labels
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                height, width = image.shape[:2]
                
                # Get bounding boxes in YOLO format directly
                bboxes = []
                class_ids = []
                
                with open(label_path, 'r') as f:
                    lines = f.readlines()
                
                for line in lines:
                    parts = line.strip().split(' ')
                    cls = int(parts[0])
                    # YOLO format: center_x, center_y, width, height (normalized)
                    cx, cy, w, h = map(float, parts[1:5])
                    
                    # Keep in YOLO format for Albumentations
                    bboxes.append([cx, cy, w, h])
                    class_ids.append(cls)
                
                # Skip if no bounding boxes (shouldn't happen, but just in case)
                if not bboxes:
                    continue
                
                try:
                    # Apply augmentation - using YOLO format
                    transformed = augmentation_pipeline(
                        image=image,
                        bboxes=bboxes,
                        class_ids=class_ids
                    )
                    
                    # Get augmented data
                    aug_image = transformed['image']
                    aug_bboxes = transformed['bboxes']
                    aug_class_ids = transformed['class_ids']
                    
                    # Save augmented image
                    aug_img_name = f"aug_{i}_{img_name}"
                    aug_label_name = aug_img_name.replace('.png', '.txt')
                    
                    cv2.imwrite(os.path.join(augmented_dir, "images", aug_img_name), 
                              cv2.cvtColor(aug_image, cv2.COLOR_RGB2BGR))
                    
                    # Save labels in YOLO format (they're already in YOLO format)
                    with open(os.path.join(augmented_dir, "labels", aug_label_name), 'w') as f:
                        for bbox, cls in zip(aug_bboxes, aug_class_ids):
                            cx, cy, w, h = bbox
                            f.write(f"{cls} {cx} {cy} {w} {h}\n")
                    
                    augmentation_count += 1
                    
                except Exception as e:
                    print(f"Error during augmentation: {e}")
                    # If augmentation fails, just duplicate the image
                    dup_img_name = f"dup_{i}_{img_name}"
                    dup_label_name = dup_img_name.replace('.png', '.txt')
                    
                    shutil.copy(img_path, os.path.join(augmented_dir, "images", dup_img_name))
                    shutil.copy(label_path, os.path.join(augmented_dir, "labels", dup_label_name))
                    
                    duplication_count += 1
            else:
                # Just duplicate the image
                dup_img_name = f"dup_{i}_{img_name}"
                dup_label_name = dup_img_name.replace('.png', '.txt')
                
                shutil.copy(img_path, os.path.join(augmented_dir, "images", dup_img_name))
                shutil.copy(label_path, os.path.join(augmented_dir, "labels", dup_label_name))
                
                duplication_count += 1
        
        print(f"Created {augmentation_count} augmented and {duplication_count} duplicated images for {class_name}")
    
    # Merge augmented data with original training data
    merge_augmented_data(train_images_dir, train_labels_dir, augmented_dir)
    
    # Visualize the balanced dataset
    visualize_augmentations()
    count_class_distribution()
def merge_augmented_data(train_images_dir, train_labels_dir, augmented_dir):
    """Merge augmented data with original training data"""
    print("Merging augmented data with original training data...")
    
    # Copy all augmented images to training directory
    for img_file in os.listdir(os.path.join(augmented_dir, "images")):
        shutil.copy(
            os.path.join(augmented_dir, "images", img_file),
            os.path.join(train_images_dir, img_file)
        )
    
    # Copy all augmented labels to training directory
    for label_file in os.listdir(os.path.join(augmented_dir, "labels")):
        shutil.copy(
            os.path.join(augmented_dir, "labels", label_file),
            os.path.join(train_labels_dir, label_file)
        )
    
    print("Data merging complete!")

def visualize_augmentations(num_examples=3):
    """Visualize some examples of augmentations for verification"""
    train_images_dir = os.path.join(OUTPUT_DIR, "images", "train")
    train_labels_dir = os.path.join(OUTPUT_DIR, "labels", "train")
    
    # Find augmented images
    augmented_images = [f for f in os.listdir(train_images_dir) if f.startswith("aug_")]
    
    if not augmented_images:
        print("No augmented images found to visualize.")
        return
    
    # Pick random samples to show
    samples = random.sample(augmented_images, min(num_examples, len(augmented_images)))
    
    # Class names for visualization
    class_names = ['Car', 'Van', 'Truck', 'Pedestrian', 'Cyclist']
    colors = [(0, 255, 0), (255, 0, 0), (0, 0, 255), (255, 255, 0), (0, 255, 255)]
    
    fig, axes = plt.subplots(1, len(samples), figsize=(18, 6))
    
    for i, img_file in enumerate(samples):
        img_path = os.path.join(train_images_dir, img_file)
        label_path = os.path.join(train_labels_dir, img_file.replace('.png', '.txt'))
        
        # Read image
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        # Get shape for denormalization
        height, width = img.shape[:2]
        
        # Display image
        if len(samples) == 1:
            ax = axes
        else:
            ax = axes[i]
            
        ax.imshow(img)
        ax.set_title(f"Augmented Image {i+1}")
        ax.axis('off')
        
        # Read and plot bounding boxes
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                lines = f.readlines()
                
            for line in lines:
                parts = line.strip().split(' ')
                # Fix: Handle float values in class IDs by converting to float first, then int
                cls_id = int(float(parts[0]))
                cx, cy, w, h = map(float, parts[1:5])
                
                # Convert normalized YOLO to pixel coordinates
                x1 = int((cx - w/2) * width)
                y1 = int((cy - h/2) * height)
                x2 = int((cx + w/2) * width)
                y2 = int((cy + h/2) * height)
                
                # Draw rectangle
                rect = plt.Rectangle((x1, y1), x2-x1, y2-y1, 
                                    fill=False, edgecolor=np.array(colors[cls_id])/255, linewidth=2)
                ax.add_patch(rect)
                
                # Add label
                ax.text(x1, y1-5, class_names[cls_id], 
                        color='white', fontsize=10, 
                        bbox=dict(facecolor=np.array(colors[cls_id])/255, alpha=0.7))
                
    plt.tight_layout()
    plt.savefig(os.path.join(DATA_ROOT, 'augmentation_examples.png'))
    plt.show()
    
def count_class_distribution():
    """Count and display class distribution after balancing"""
    train_labels_dir = os.path.join(OUTPUT_DIR, "labels", "train")
    
    # Class names
    class_names = ['Car', 'Van', 'Truck', 'Pedestrian', 'Cyclist']
    
    # Count objects per class
    class_counts = {i: 0 for i in range(len(class_names))}
    image_counts = {i: 0 for i in range(len(class_names))}
    
    print("Counting class distribution...")
    for label_file in tqdm(os.listdir(train_labels_dir)):
        label_path = os.path.join(train_labels_dir, label_file)
        
        with open(label_path, 'r') as f:
            lines = f.readlines()
            
        # Track which classes appear in this image
        classes_in_image = set()
            
        for line in lines:
            try:
                # Fix: Handle float values in class IDs by converting to float first, then int
                cls_id = int(float(line.strip().split(' ')[0]))
                if cls_id < len(class_names):  # Make sure it's a valid class
                    class_counts[cls_id] += 1
                    classes_in_image.add(cls_id)
            except (ValueError, IndexError) as e:
                print(f"Warning: Error processing line in {label_file}: {line.strip()}")
                print(f"Error: {e}")
                continue
        
        # Update image counts
        for cls_id in classes_in_image:
            image_counts[cls_id] += 1
    
    # Display counts
    print("\nClass distribution after balancing:")
    print(f"{'Class':<10} {'Objects':<8} {'Images':<8}")
    print("-" * 30)
    for i, name in enumerate(class_names):
        print(f"{name:<10} {class_counts[i]:<8} {image_counts[i]:<8}")
    
    # Plot distribution
    plt.figure(figsize=(12, 6))
    
    x = np.arange(len(class_names))
    width = 0.35
    
    plt.bar(x - width/2, [class_counts[i] for i in range(len(class_names))], width, label='Objects')
    plt.bar(x + width/2, [image_counts[i] for i in range(len(class_names))], width, label='Images')
    
    plt.xlabel('Class')
    plt.ylabel('Count')
    plt.title('Class Distribution After Balancing')
    plt.xticks(x, class_names)
    plt.legend()
    plt.tight_layout()
    plt.savefig(os.path.join(DATA_ROOT, 'balanced_class_distribution.png'))
    plt.show()
    
    return class_counts, image_counts

def create_data_yaml():
    """Create dataset YAML configuration file for YOLO"""
    yaml_content = f"""
# KITTI dataset for YOLO
path: {OUTPUT_DIR}
train: images/train
val: images/val

# Classes
names:
  0: Car
  1: Van
  2: Truck
  3: Pedestrian
  4: Cyclist
"""
    
    with open(os.path.join(OUTPUT_DIR, 'kitti.yaml'), 'w') as f:
        f.write(yaml_content)
    
    print(f"Created dataset config at {os.path.join(OUTPUT_DIR, 'kitti.yaml')}")

def class_weighting_strategy():
    """
    Handle class imbalance, with special focus on car class which is more prevalent
    For YOLOv8, we can use the following approaches:
    1. Adjust class weights in the loss function
    2. Under-sample the majority class or over-sample minority classes
    3. Use augmentation techniques to increase diversity
    
    This function creates a balanced sampling strategy
    """
    # Count instances per class
    train_labels_dir = os.path.join(OUTPUT_DIR, "labels", "train")
    class_counts = {i: 0 for i in range(len(kitti_to_yolo))}
    
    for label_file in os.listdir(train_labels_dir):
        with open(os.path.join(train_labels_dir, label_file), 'r') as f:
            lines = f.readlines()
            for line in lines:
                try:
                    # Fix: Handle float values in class IDs by converting to float first, then int
                    class_id = int(float(line.strip().split(' ')[0]))
                    if class_id in class_counts:  # Make sure it's a valid class
                        class_counts[class_id] += 1
                except (ValueError, IndexError) as e:
                    print(f"Warning: Error processing line in {label_file}: {line.strip()}")
                    continue
    
    total_instances = sum(class_counts.values())
    class_weights = {cls: total_instances / (len(class_counts) * count) if count > 0 else 1.0 
                     for cls, count in class_counts.items()}
    
    print(f"Class counts: {class_counts}")
    print(f"Recommended class weights: {class_weights}")
    
    return class_weights
    
def train_yolo_model():
    """Train YOLOv8 model"""
    model = YOLO('yolov8n.pt')

    # Train the model
    results = model.train(
        data=os.path.join(OUTPUT_DIR, 'kitti.yaml'),
        epochs=30,
        imgsz=640,
        batch=16,
        workers=4,
        device=0 if torch.cuda.is_available() else 'cpu',
        cos_lr=True,
        patience=5,
        project='/kaggle/working/runs',  # Save to Kaggle working directory
        name='yolov8_kitti',
        verbose=True,
        save=True,
        exist_ok=True
    )
    
    # Get the best model path from training
    best_model_path = '/kaggle/working/runs/yolov8_kitti/weights/bestt.pt'
    
    # Make sure model file exists in the Kaggle working directory
    if os.path.exists(best_model_path):
        print(f"✅ Model saved successfully at: {best_model_path}")
        print("⬇️ You can download this file from the Kaggle output files section")
    else:
        print(f"❌ Model not found at expected path: {best_model_path}")
        # Try to find the model file elsewhere
        possible_paths = [
            '/kaggle/working/bestt.pt',
            os.path.join(DATA_ROOT, 'runs/yolov8_kitti/weights/bestt.pt'),
            '/kaggle/working/runs/train/weights/bestt.pt'
        ]
        
        for path in possible_paths:
            if os.path.exists(path):
                print(f"✅ Found model at alternative location: {path}")
                print("⬇️ You can download this file from the Kaggle output files section")
                break
    
    return model


def evaluate_model(model):
    """Evaluate the trained model"""
    # Run validation on the validation set
    val_results = model.val(data=os.path.join(OUTPUT_DIR, 'kitti.yaml'))
    
    # Print results
    print("Validation Results:")
    print(f"mAP@0.5: {val_results.box.map50}")
    print(f"mAP@0.5-0.95: {val_results.box.map}")
    
    # Get per-class metrics
    for i, cls_name in enumerate(['Car', 'Van', 'Truck', 'Pedestrian', 'Cyclist']):
        try:
            print(f"{cls_name} - Precision: {val_results.cls[i].precision:.4f}, "
                  f"Recall: {val_results.cls[i].recall:.4f}, "
                  f"mAP@0.5: {val_results.cls[i].map50:.4f}")
        except (IndexError, AttributeError):
            print(f"No metrics available for class {cls_name}")
    
    return val_results

def test_on_single_image(model, image_path=None):
    """Test the model on a single image from the validation set"""
    # If no image path is provided, pick a random one from validation set
    if image_path is None:
        val_dir = os.path.join(OUTPUT_DIR, "images", "val")
        val_images = os.listdir(val_dir)
        if val_images:
            image_path = os.path.join(val_dir, random.choice(val_images))
        else:
            print("No validation images found.")
            return
    
    # Run prediction
    results = model.predict(image_path, conf=0.25, save=True)
    
    # Display results
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.figure(figsize=(12, 8))
    plt.imshow(img)
    
    # Get the result for the first image
    result = results[0]
    
    # Plot bounding boxes
    boxes = result.boxes.xyxy.cpu().numpy()
    classes = result.boxes.cls.cpu().numpy().astype(int)
    confs = result.boxes.conf.cpu().numpy()
    
    class_names = ['Car', 'Van', 'Truck', 'Pedestrian', 'Cyclist']
    colors = [(0, 255, 0), (255, 0, 0), (0, 0, 255), (255, 255, 0), (0, 255, 255)]
    
    for box, cls, conf in zip(boxes, classes, confs):
        x1, y1, x2, y2 = box.astype(int)
        class_name = class_names[cls]
        color = colors[cls % len(colors)]
        
        # Draw rectangle
        plt.gca().add_patch(plt.Rectangle((x1, y1), x2-x1, y2-y1, 
                                         fill=False, edgecolor=np.array(color)/255, 
                                         linewidth=2))
        
        # Add label
        plt.text(x1, y1-10, f"{class_name} {conf:.2f}", 
                 color='white', fontsize=12, 
                 bbox=dict(facecolor=np.array(color)/255, alpha=0.7))
    
    plt.title("YOLO Detection on KITTI Dataset")
    plt.axis('off')
    plt.tight_layout()
    plt.savefig(os.path.join(DATA_ROOT, 'test_detection.png'))
    plt.show()
    
    print(f"Detected {len(boxes)} objects")
    
    # Print counts per class
    class_counts = {}
    for cls in classes:
        cls_name = class_names[cls]
        class_counts[cls_name] = class_counts.get(cls_name, 0) + 1
    
    print("Detections per class:")
    for cls_name, count in class_counts.items():
        print(f"  {cls_name}: {count}")
    
    return results

# Main execution
if __name__ == "__main__":
    print("Starting KITTI dataset preprocessing...")
    preprocess_data()
    

    implement_class_balancing(target_classes=["Cyclist", "Truck"])
     # Visualize some examples of the augmentations
    visualize_augmentations(num_examples=3)
    # Check the resulting class distribution
    count_class_distribution()
    create_data_yaml()
    print("Training YOLO model...")
    model = train_yolo_model()
    
    print("Evaluating model...")
    val_results = evaluate_model(model)
    
    print("Testing on a single image...")
    test_results = test_on_single_image(model)
    
    print("Processing complete!")
# Out:
# Starting KITTI dataset preprocessing...
# 100%|██████████| 7481/7481 [00:00<00:00, 31588.15it/s]
# Class distribution: {'Car': 28742, 'Van': 2914, 'Truck': 1094, 'Pedestrian': 4487, 'Cyclist': 1627}
# Processing training data: 100%|██████████| 5984/5984 [01:20<00:00, 74.70it/s]
# Processing validation data: 100%|██████████| 1497/1497 [00:20<00:00, 72.53it/s]
# Implementing class balancing for: ['Cyclist', 'Truck']
# Scanning dataset for target classes...
# 100%|██████████| 6029/6029 [00:00<00:00, 24571.97it/s]
# /tmp/ipykernel_55/3107781998.py:246: UserWarning: Argument(s) 'fog_coef_lower, fog_coef_upper' are not valid for transform RandomFog
#   A.RandomFog(fog_coef_lower=0.1, fog_coef_upper=0.3, p=0.1),  # Note: these params might need to be checked
# Found images with target classes: {4: 884, 2: 883}
# Target counts per class: {4: 884, 2: 884}
# Generating balanced dataset...
# No additional images needed for Cyclist
# Generating 1 additional images for Truck
# 100%|██████████| 1/1 [00:00<00:00, 21.10it/s]
# Created 1 augmented and 0 duplicated images for Truck
# Merging augmented data with original training data...
# Data merging complete!
# Counting class distribution...
# 100%|██████████| 6030/6030 [00:00<00:00, 30355.28it/s]
# Class distribution after balancing:
# Class      Objects  Images
# ------------------------------
# Car        23185    5398
# Van        2310     1702
# Truck      945      890
# Pedestrian 3652     1434
# Cyclist    1306     929
# Counting class distribution...
# 100%|██████████| 6030/6030 [00:00<00:00, 29494.71it/s]
# Class distribution after balancing:
# Class      Objects  Images
# ------------------------------
# Car        23185    5398
# Van        2310     1702
# Truck      945      890
# Pedestrian 3652     1434
# Cyclist    1306     929
# Created dataset config at /content/kitti/yolo_dataset/kitti.yaml
# Training YOLO model...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 7.87MB/s]
# Ultralytics 8.3.124 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/content/kitti/yolo_dataset/kitti.yaml, epochs=30, time=None, patience=5, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=4, project=/kaggle/working/runs, name=yolov8_kitti, exist_ok=True, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=True, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, cutmix=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, cfg=None, tracker=botsort.yaml, save_dir=/kaggle/working/runs/yolov8_kitti
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 29.6MB/s]
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752287  ultralytics.nn.modules.head.Detect           [5, [64, 128, 256]]
# Model summary: 129 layers, 3,011,823 parameters, 3,011,807 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 121MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3428.4±646.1 MB/s, size: 842.7 KB)
# train: Scanning /content/kitti/yolo_dataset/labels/train... 6030 images, 0 backgrounds, 0 corrupt: 100%|██████████| 6030/6030 [00:29<00:00, 202.90it/s]
# train: New cache created: /content/kitti/yolo_dataset/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2298.2±1971.6 MB/s, size: 826.8 KB)
# val: Scanning /content/kitti/yolo_dataset/labels/val... 1497 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1497/1497 [00:07<00:00, 192.25it/s]
# val: New cache created: /content/kitti/yolo_dataset/labels/val.cache
# Plotting labels to /kaggle/working/runs/yolov8_kitti/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/yolov8_kitti
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      2.21G      1.361      1.602      1.078        127        640: 100%|██████████| 377/377 [01:17<00:00,  4.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:10<00:00,  4.50it/s]
#                    all       1497       7726      0.556      0.482       0.51      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      2.23G      1.255      1.079      1.055        186        640: 100%|██████████| 377/377 [01:13<00:00,  5.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:09<00:00,  5.19it/s]
#                    all       1497       7726      0.677      0.545      0.597      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      2.23G      1.236     0.9788      1.052        139        640: 100%|██████████| 377/377 [01:12<00:00,  5.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.50it/s]
#                    all       1497       7726      0.696      0.533      0.603      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      2.23G      1.194     0.9128      1.039        161        640: 100%|██████████| 377/377 [01:12<00:00,  5.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.40it/s]
#                    all       1497       7726      0.728      0.559       0.64      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      2.23G      1.159     0.8559      1.026        151        640: 100%|██████████| 377/377 [01:12<00:00,  5.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.50it/s]
#                    all       1497       7726      0.728      0.576      0.665      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      2.23G      1.137     0.8221      1.017        149        640: 100%|██████████| 377/377 [01:11<00:00,  5.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.51it/s]
#                    all       1497       7726      0.757      0.635      0.702       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      2.23G      1.111     0.7939      1.005        129        640: 100%|██████████| 377/377 [01:11<00:00,  5.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.51it/s]
#                    all       1497       7726      0.766      0.657      0.736      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      2.23G      1.089     0.7687          1        128        640: 100%|██████████| 377/377 [01:12<00:00,  5.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.54it/s]
#                    all       1497       7726      0.788      0.637      0.729      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      2.23G      1.074     0.7439     0.9934        135        640: 100%|██████████| 377/377 [01:11<00:00,  5.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.33it/s]
#                    all       1497       7726      0.737       0.67       0.73      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      2.23G      1.057     0.7303     0.9866        148        640: 100%|██████████| 377/377 [01:12<00:00,  5.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.54it/s]
#                    all       1497       7726      0.823      0.651      0.761      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      2.23G      1.043     0.7124     0.9824        139        640: 100%|██████████| 377/377 [01:12<00:00,  5.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.51it/s]
#                    all       1497       7726      0.824      0.669      0.774      0.515
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      2.23G       1.03     0.6973     0.9795        133        640: 100%|██████████| 377/377 [01:12<00:00,  5.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.55it/s]
#                    all       1497       7726       0.85      0.671      0.785       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      2.23G      1.017     0.6855     0.9732        144        640: 100%|██████████| 377/377 [01:11<00:00,  5.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.39it/s]
#                    all       1497       7726      0.865      0.694        0.8      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      2.23G     0.9926     0.6567     0.9643         99        640: 100%|██████████| 377/377 [01:12<00:00,  5.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.50it/s]
#                    all       1497       7726      0.837      0.709      0.797      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      2.23G     0.9874     0.6503     0.9627        151        640: 100%|██████████| 377/377 [01:11<00:00,  5.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.54it/s]
#                    all       1497       7726      0.868      0.708      0.815      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      2.23G     0.9715     0.6356     0.9562        178        640: 100%|██████████| 377/377 [01:12<00:00,  5.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.52it/s]
#                    all       1497       7726      0.867      0.716      0.823      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      2.23G     0.9588     0.6283     0.9526        128        640: 100%|██████████| 377/377 [01:11<00:00,  5.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.53it/s]
#                    all       1497       7726      0.863      0.737      0.834      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      2.23G     0.9447     0.6126     0.9458        142        640: 100%|██████████| 377/377 [01:12<00:00,  5.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.52it/s]
#                    all       1497       7726      0.878      0.731      0.841      0.585
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      2.23G     0.9293     0.6019     0.9439        137        640: 100%|██████████| 377/377 [01:11<00:00,  5.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.58it/s]
#                    all       1497       7726        0.9       0.74      0.847      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      2.23G     0.9161     0.5902     0.9383        126        640: 100%|██████████| 377/377 [01:11<00:00,  5.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.59it/s]
#                    all       1497       7726      0.875      0.765      0.858      0.602
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      2.23G     0.9006     0.5666     0.9312         41        640: 100%|██████████| 377/377 [01:12<00:00,  5.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.61it/s]
#                    all       1497       7726      0.875      0.764      0.852      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      2.23G     0.8781     0.5473      0.924         84        640: 100%|██████████| 377/377 [01:11<00:00,  5.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.54it/s]
#                    all       1497       7726      0.889      0.756      0.853      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      2.23G     0.8634     0.5345     0.9198         57        640: 100%|██████████| 377/377 [01:11<00:00,  5.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.52it/s]
#                    all       1497       7726      0.888      0.766      0.861      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      2.23G     0.8529     0.5268     0.9137         99        640: 100%|██████████| 377/377 [01:10<00:00,  5.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.61it/s]
#                    all       1497       7726        0.9      0.765      0.862      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      2.23G     0.8393     0.5174     0.9101         70        640: 100%|██████████| 377/377 [01:10<00:00,  5.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.60it/s]
#                    all       1497       7726      0.896      0.775      0.868      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      2.23G     0.8293     0.5116     0.9097         68        640: 100%|██████████| 377/377 [01:10<00:00,  5.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.36it/s]
#                    all       1497       7726      0.897      0.779       0.87      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      2.23G     0.8235     0.5067     0.9043         59        640: 100%|██████████| 377/377 [01:10<00:00,  5.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.58it/s]
#                    all       1497       7726      0.912      0.779      0.875      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      2.23G     0.8184      0.501     0.9042         66        640: 100%|██████████| 377/377 [01:10<00:00,  5.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.27it/s]
#                    all       1497       7726      0.894      0.788      0.875      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      2.23G       0.81     0.4987     0.9019         76        640: 100%|██████████| 377/377 [01:10<00:00,  5.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:08<00:00,  5.54it/s]
#                    all       1497       7726      0.888      0.793      0.875      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      2.23G     0.8076      0.497     0.9023         75        640: 100%|██████████| 377/377 [01:10<00:00,  5.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:09<00:00,  5.17it/s]
#                    all       1497       7726      0.883      0.796      0.874      0.628
#
# 30 epochs completed in 0.674 hours.
# Optimizer stripped from /kaggle/working/runs/yolov8_kitti/weights/last.pt, 6.2MB
# Optimizer stripped from /kaggle/working/runs/yolov8_kitti/weights/best.pt, 6.2MB
#
# Validating /kaggle/working/runs/yolov8_kitti/weights/best.pt...
# Ultralytics 8.3.124 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:09<00:00,  4.75it/s]
#                    all       1497       7726       0.89      0.791      0.874      0.628
#                    Car       1331       5731      0.899      0.891      0.945      0.747
#                    Van        461        627      0.901      0.801      0.904      0.683
#                  Truck        191        197      0.947      0.914      0.941      0.756
#             Pedestrian        351        844      0.827      0.632      0.759      0.435
#                Cyclist        215        327      0.877      0.719      0.819      0.519
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# Speed: 0.1ms preprocess, 0.9ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /kaggle/working/runs/yolov8_kitti
# ❌ Model not found at expected path: /kaggle/working/runs/yolov8_kitti/weights/bestt.pt
# Evaluating model...
# Ultralytics 8.3.124 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3862.0±1330.7 MB/s, size: 843.9 KB)
# val: Scanning /content/kitti/yolo_dataset/labels/val.cache... 1497 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1497/1497 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 94/94 [00:10<00:00,  9.15it/s]
#                    all       1497       7726      0.884      0.797      0.875      0.628
#                    Car       1331       5731      0.892      0.895      0.945      0.748
#                    Van        461        627      0.897      0.808      0.904      0.683
#                  Truck        191        197      0.945      0.914      0.942      0.754
#             Pedestrian        351        844      0.809      0.645      0.763      0.435
#                Cyclist        215        327      0.876      0.722      0.824      0.521
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# Speed: 0.1ms preprocess, 1.1ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /kaggle/working/runs/yolov8_kitti
# Validation Results:
# mAP@0.5: 0.875397602589629
# mAP@0.5-0.95: 0.6281749221022935
# No metrics available for class Car
# No metrics available for class Van
# No metrics available for class Truck
# No metrics available for class Pedestrian
# No metrics available for class Cyclist
# Testing on a single image...
#
# image 1/1 /content/kitti/yolo_dataset/images/val/002147.png: 224x640 18 Cars, 3 Vans, 1 Pedestrian, 34.8ms
# Speed: 1.7ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 640)
# Results saved to /kaggle/working/runs/yolov8_kitti
# Detected 22 objects
# Detections per class:
#   Car: 18
#   Van: 3
#   Pedestrian: 1
# Processing complete!
